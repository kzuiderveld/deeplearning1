# %% [markdown]
# # Training a better model

# %%
# %matplotlib inline
import utils3
from utils3 import *
# Out:
# Using Theano backend.
# /home/karel/anaconda3/lib/python3.6/site-packages/theano/gpuarray/dnn.py:135: UserWarning: Your cuDNN version is more recent than Theano. If you encounter problems, try updating Theano or downgrading cuDNN to version 5.1.
#   warnings.warn("Your cuDNN version is more recent than "
# Using cuDNN version 6020 on context None
# Mapped name None to device cuda: Graphics Device (0000:02:00.0)

# %%
#path = "data/dogscats/sample/"
path = "data/dogscats/"
model_path = path + 'models/'
if not os.path.exists(model_path): os.mkdir(model_path)

batch_size=64

# %% [markdown]
# ## Are we underfitting?

# %% [markdown]
# Our validation accuracy so far has generally been higher than our training accuracy. That leads to two obvious questions:
#
# 1. How is this possible?
# 2. Is this desirable?
#
# The answer to (1) is that this is happening because of *dropout*. Dropout refers to a layer that randomly deletes (i.e. sets to zero) each activation in the previous layer with probability *p* (generally 0.5). This only happens during training, not when calculating the accuracy on the validation set, which is why the validation set can show higher accuracy than the training set.
#
# The purpose of dropout is to avoid overfitting. By deleting parts of the neural network at random during training, it ensures that no one part of the network can overfit to one part of the training set. The creation of dropout was one of the key developments in deep learning, and has allowed us to create rich models without overfitting. However, it can also result in underfitting if overused, and this is something we should be careful of with our model.
#
# So the answer to (2) is: this is probably not desirable. It is likely that we can get better validation set results with less (or no) dropout, if we're seeing that validation accuracy is higher than training accuracy - a strong sign of underfitting. So let's try removing dropout entirely, and see what happens!
#
# (We had dropout in this model already because the VGG authors found it necessary for the imagenet competition. But that doesn't mean it's necessary for dogs v cats, so we will do our own analysis of regularization approaches from scratch.)

# %% [markdown]
# ## Removing dropout

# %% [markdown]
# Our high level approach here will be to start with our fine-tuned cats vs dogs model (with dropout), then fine-tune all the dense layers, after removing dropout from them. The steps we will take are:
# - Re-create and load our modified VGG model with binary dependent (i.e. dogs v cats)
# - Split the model between the convolutional (*conv*) layers and the dense layers
# - Pre-calculate the output of the conv layers, so that we don't have to redundently re-calculate them on every epoch
# - Create a new model with just the dense layers, and dropout p set to zero
# - Train this new model using the output of the conv layers as training data.

# %% [markdown]
# As before we need to start with a working model, so let's bring in our working VGG 16 model and change it to predict our binary dependent...

# %%
model = vgg_ft(2)

# %% [markdown]
# ...and load our fine-tuned weights.

# %%
model.load_weights(model_path+'finetune3.h5')

# %% [markdown]
# We're going to be training a number of iterations without dropout, so it would be best for us to pre-calculate the input to the fully connected layers - i.e. the *Flatten()* layer. We'll start by finding this layer in our model, and creating a new model that contains just the layers up to and including this layer:

# %%
layers = model.layers

# %%
last_conv_idx = [index for index,layer in enumerate(layers) 
                     if type(layer) is Conv2D][-1]

# %%
last_conv_idx
# Out:
# 30

# %%
layers[last_conv_idx]

# %%
conv_layers = layers[:last_conv_idx+1]
conv_model = Sequential(conv_layers)
# Dense layers - also known as fully connected or 'FC' layers
fc_layers = layers[last_conv_idx+1:]

# %% [markdown]
# Now we can use the exact same approach to creating features as we used when we created the linear model from the imagenet predictions in the last lesson - it's only the model that has changed. As you're seeing, there's a fairly small number of "recipes" that can get us a long way!

# %%
batches = get_batches(path+'train', shuffle=False, batch_size=batch_size)
val_batches = get_batches(path+'valid', shuffle=False, batch_size=batch_size)

val_classes = val_batches.classes
trn_classes = batches.classes
val_labels = onehot(val_classes)
trn_labels = onehot(trn_classes)
# Out:
# Found 23000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
val_steps = ceil(val_batches.samples/val_batches.batch_size)
trn_steps = ceil(batches.samples / batches.batch_size)
trn_steps
# Out:
# 360

# %%
val_features = conv_model.predict_generator(val_batches, val_steps)

# %%
trn_features = conv_model.predict_generator(batches, trn_steps)

# %%
save_array(model_path + 'train_convlayer_features.bc', trn_features)
save_array(model_path + 'valid_convlayer_features.bc', val_features)

# %%
trn_features = load_array(model_path+'train_convlayer_features.bc')
val_features = load_array(model_path+'valid_convlayer_features.bc')

# %%
trn_features.shape
# Out:
# (23000, 512, 14, 14)

# %% [markdown]
# For our new fully connected model, we'll create it using the exact same architecture as the last layers of VGG 16, so that we can conveniently copy pre-trained weights over from that model. However, we'll set the dropout layer's p values to zero, so as to effectively remove dropout.

# %%
# Copy the weights from the pre-trained model.
# NB: Since we're removing dropout, we want to half the weights
def proc_wgts(layer): return [o/2 for o in layer.get_weights()]

# %%
# Such a finely tuned model needs to be updated very slowly!
opt = RMSprop(lr=0.00001, rho=0.7)

# %%
def get_fc_model():
    model = Sequential([
        MaxPooling2D(input_shape=conv_layers[-1].output_shape[1:]),
        Flatten(),
        Dense(4096, activation='relu'),
        Dropout(0.),
        Dense(4096, activation='relu'),
        Dropout(0.),
        Dense(2, activation='softmax')
        ])

    for l1,l2 in zip(model.layers, fc_layers): l1.set_weights(proc_wgts(l2))

    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
fc_model = get_fc_model()

# %% [markdown]
# And fit the model in the usual way:

# %%
fc_model.fit(trn_features, trn_labels, epochs=8, 
             batch_size=batch_size, validation_data=(val_features, val_labels))
# Out:
# Train on 23000 samples, validate on 2000 samples
# Epoch 1/8
# 23000/23000 [==============================] - 8s - loss: 0.2679 - acc: 0.9817 - val_loss: 0.2377 - val_acc: 0.9830
# Epoch 2/8
# 23000/23000 [==============================] - 7s - loss: 0.2160 - acc: 0.9854 - val_loss: 0.3157 - val_acc: 0.9775
# Epoch 3/8
# 23000/23000 [==============================] - 8s - loss: 0.2090 - acc: 0.9860 - val_loss: 0.2316 - val_acc: 0.9840
# Epoch 4/8
# 23000/23000 [==============================] - 8s - loss: 0.1738 - acc: 0.9884 - val_loss: 0.2094 - val_acc: 0.9855
# Epoch 5/8
# 23000/23000 [==============================] - 8s - loss: 0.1573 - acc: 0.9897 - val_loss: 0.3681 - val_acc: 0.9745
# Epoch 6/8
# 23000/23000 [==============================] - 8s - loss: 0.1365 - acc: 0.9909 - val_loss: 0.1918 - val_acc: 0.9870
# Epoch 7/8
# 23000/23000 [==============================] - 8s - loss: 0.1404 - acc: 0.9907 - val_loss: 0.2125 - val_acc: 0.9855
# Epoch 8/8
# 23000/23000 [==============================] - 8s - loss: 0.1222 - acc: 0.9919 - val_loss: 0.2235 - val_acc: 0.9860

# %%
fc_model.save_weights(model_path+'no_dropout.h5')

# %%
fc_model.load_weights(model_path+'no_dropout.h5')

# %% [markdown]
# # Reducing overfitting

# %% [markdown]
# Now that we've gotten the model to overfit, we can take a number of steps to reduce this.

# %% [markdown]
# ## Approaches to reducing overfitting

# %% [markdown]
# We do not necessarily need to rely on dropout or other regularization approaches to reduce overfitting. There are other techniques we should try first, since regularlization, by definition, biases our model towards simplicity - which we only want to do if we know that's necessary. This is the order that we recommend using for reducing overfitting (more details about each in a moment):
#
# 1. Add more data
# 2. Use data augmentation
# 3. Use architectures that generalize well
# 4. Add regularization
# 5. Reduce architecture complexity.
#
# We'll assume that you've already collected as much data as you can, so step (1) isn't relevant (this is true for most Kaggle competitions, for instance). So the next step (2) is data augmentation. This refers to creating additional synthetic data, based on reasonable modifications of your input data. For images, this is likely to involve one or more of: flipping, rotation, zooming, cropping, panning, minor color changes.
#
# Which types of augmentation are appropriate depends on your data. For regular photos, for instance, you'll want to use horizontal flipping, but not vertical flipping (since an upside down car is much less common than a car the right way up, for instance!)
#
# We recommend *always* using at least some light data augmentation, unless you have so much data that your model will never see the same input twice.

# %% [markdown]
# ## About data augmentation

# %% [markdown]
# Keras comes with very convenient features for automating data augmentation. You simply define what types and maximum amounts of augmentation you want, and keras ensures that every item of every batch randomly is changed according to these settings. Here's how to define a generator that includes data augmentation:

# %%
# dim_ordering='tf' uses tensorflow dimension ordering,
#   which is the same order as matplotlib uses for display.
# Therefore when just using for display purposes, this is more convenient
gen = image.ImageDataGenerator(rotation_range=10, width_shift_range=0.1, 
       height_shift_range=0.1, shear_range=0.15, zoom_range=0.1, 
       channel_shift_range=10., horizontal_flip=True, data_format='channels_last')

# %%
# !ls data/dogscats/train/cats
# Out:
# cat.0.jpg      cat.12249.jpg  cat.3252.jpg  cat.5504.jpg  cat.7752.jpg
# cat.10001.jpg  cat.1224.jpg   cat.3253.jpg  cat.5505.jpg  cat.7753.jpg
# cat.10002.jpg  cat.12250.jpg  cat.3254.jpg  cat.5506.jpg  cat.7754.jpg
# cat.10003.jpg  cat.12251.jpg  cat.3256.jpg  cat.5507.jpg  cat.7755.jpg
# cat.10004.jpg  cat.12252.jpg  cat.3257.jpg  cat.5508.jpg  cat.7756.jpg
# cat.10005.jpg  cat.12253.jpg  cat.3258.jpg  cat.5509.jpg  cat.7757.jpg
# cat.10006.jpg  cat.12254.jpg  cat.3259.jpg  cat.550.jpg   cat.7758.jpg
# cat.10007.jpg  cat.12255.jpg  cat.325.jpg   cat.5510.jpg  cat.7759.jpg
# cat.10008.jpg  cat.12257.jpg  cat.3260.jpg  cat.5511.jpg  cat.775.jpg
# cat.10009.jpg  cat.12258.jpg  cat.3261.jpg  cat.5513.jpg  cat.7760.jpg
# cat.1000.jpg   cat.12259.jpg  cat.3262.jpg  cat.5514.jpg  cat.7761.jpg
# cat.10010.jpg  cat.1225.jpg   cat.3263.jpg  cat.5515.jpg  cat.7762.jpg
# cat.10011.jpg  cat.12260.jpg  cat.3264.jpg  cat.5516.jpg  cat.7763.jpg
# cat.10012.jpg  cat.12261.jpg  cat.3265.jpg  cat.5517.jpg  cat.7764.jpg
# cat.10013.jpg  cat.12262.jpg  cat.3266.jpg  cat.5518.jpg  cat.7765.jpg
# cat.10014.jpg  cat.12263.jpg  cat.3267.jpg  cat.5519.jpg  cat.7766.jpg
# cat.10015.jpg  cat.12264.jpg  cat.3268.jpg  cat.551.jpg   cat.7767.jpg
# cat.10016.jpg  cat.12265.jpg  cat.326.jpg   cat.5520.jpg  cat.7768.jpg
# cat.10017.jpg  cat.12266.jpg  cat.3270.jpg  cat.5521.jpg  cat.7769.jpg
# cat.10018.jpg  cat.12267.jpg  cat.3271.jpg  cat.5522.jpg  cat.776.jpg
# cat.10019.jpg  cat.12268.jpg  cat.3272.jpg  cat.5523.jpg  cat.7770.jpg
# cat.1001.jpg   cat.12269.jpg  cat.3273.jpg  cat.5524.jpg  cat.7771.jpg
# cat.10020.jpg  cat.1226.jpg   cat.3274.jpg  cat.5525.jpg  cat.7772.jpg
# cat.10021.jpg  cat.12270.jpg  cat.3275.jpg  cat.5526.jpg  cat.7773.jpg
# cat.10022.jpg  cat.12271.jpg  cat.3276.jpg  cat.5527.jpg  cat.7774.jpg
# cat.10023.jpg  cat.12272.jpg  cat.3277.jpg  cat.5528.jpg  cat.7776.jpg
# cat.10024.jpg  cat.12273.jpg  cat.3278.jpg  cat.5529.jpg  cat.7777.jpg
# cat.10025.jpg  cat.12274.jpg  cat.3279.jpg  cat.552.jpg   cat.7778.jpg
# cat.10026.jpg  cat.12275.jpg  cat.327.jpg   cat.5530.jpg  cat.7779.jpg
# cat.10027.jpg  cat.12276.jpg  cat.3280.jpg  cat.5531.jpg  cat.777.jpg
# cat.10028.jpg  cat.12279.jpg  cat.3281.jpg  cat.5532.jpg  cat.7780.jpg
# cat.10029.jpg  cat.1227.jpg   cat.3282.jpg  cat.5534.jpg  cat.7781.jpg
# cat.1002.jpg   cat.12280.jpg  cat.3283.jpg  cat.5535.jpg  cat.7782.jpg
# cat.10030.jpg  cat.12281.jpg  cat.3285.jpg  cat.5536.jpg  cat.7783.jpg
# cat.10031.jpg  cat.12282.jpg  cat.3286.jpg  cat.5537.jpg  cat.7784.jpg
# cat.10032.jpg  cat.12283.jpg  cat.3287.jpg  cat.5538.jpg  cat.7785.jpg
# cat.10033.jpg  cat.12284.jpg  cat.3288.jpg  cat.5539.jpg  cat.7786.jpg
# cat.10034.jpg  cat.12286.jpg  cat.3289.jpg  cat.553.jpg   cat.7787.jpg
# cat.10035.jpg  cat.12287.jpg  cat.328.jpg   cat.5540.jpg  cat.7788.jpg
# cat.10036.jpg  cat.12288.jpg  cat.3290.jpg  cat.5541.jpg  cat.7789.jpg
# cat.10037.jpg  cat.12289.jpg  cat.3291.jpg  cat.5542.jpg  cat.778.jpg
# cat.10038.jpg  cat.1228.jpg   cat.3292.jpg  cat.5543.jpg  cat.7790.jpg
# cat.10039.jpg  cat.12290.jpg  cat.3293.jpg  cat.5544.jpg  cat.7791.jpg
# cat.1003.jpg   cat.12291.jpg  cat.3294.jpg  cat.5545.jpg  cat.7792.jpg
# cat.10040.jpg  cat.12292.jpg  cat.3295.jpg  cat.5546.jpg  cat.7793.jpg
# cat.10041.jpg  cat.12293.jpg  cat.3296.jpg  cat.5547.jpg  cat.7794.jpg
# cat.10042.jpg  cat.12294.jpg  cat.3297.jpg  cat.5548.jpg  cat.7795.jpg
# cat.10043.jpg  cat.12295.jpg  cat.3299.jpg  cat.5549.jpg  cat.7796.jpg
# cat.10044.jpg  cat.12296.jpg  cat.329.jpg   cat.554.jpg   cat.7797.jpg
# cat.10045.jpg  cat.12297.jpg  cat.32.jpg    cat.5550.jpg  cat.7798.jpg
# cat.10046.jpg  cat.12298.jpg  cat.3300.jpg  cat.5551.jpg  cat.7799.jpg
# cat.10047.jpg  cat.12299.jpg  cat.3301.jpg  cat.5552.jpg  cat.779.jpg
# cat.10048.jpg  cat.1229.jpg   cat.3302.jpg  cat.5553.jpg  cat.77.jpg
# cat.10049.jpg  cat.122.jpg    cat.3303.jpg  cat.5554.jpg  cat.7800.jpg
# cat.1004.jpg   cat.12300.jpg  cat.3305.jpg  cat.5555.jpg  cat.7801.jpg
# cat.10050.jpg  cat.12302.jpg  cat.3306.jpg  cat.5556.jpg  cat.7802.jpg
# cat.10051.jpg  cat.12303.jpg  cat.3307.jpg  cat.5557.jpg  cat.7803.jpg
# cat.10052.jpg  cat.12304.jpg  cat.3308.jpg  cat.5558.jpg  cat.7804.jpg
# cat.10053.jpg  cat.12305.jpg  cat.3309.jpg  cat.5559.jpg  cat.7805.jpg
# cat.10054.jpg  cat.12306.jpg  cat.330.jpg   cat.555.jpg   cat.7806.jpg
# cat.10055.jpg  cat.12307.jpg  cat.3310.jpg  cat.5560.jpg  cat.7807.jpg
# cat.10058.jpg  cat.12308.jpg  cat.3311.jpg  cat.5561.jpg  cat.7808.jpg
# cat.10059.jpg  cat.1230.jpg   cat.3312.jpg  cat.5562.jpg  cat.7809.jpg
# cat.1005.jpg   cat.12310.jpg  cat.3313.jpg  cat.5563.jpg  cat.780.jpg
# cat.10060.jpg  cat.12311.jpg  cat.3314.jpg  cat.5564.jpg  cat.7810.jpg
# cat.10062.jpg  cat.12312.jpg  cat.3315.jpg  cat.5565.jpg  cat.7811.jpg
# cat.10063.jpg  cat.12313.jpg  cat.3316.jpg  cat.5566.jpg  cat.7813.jpg
# cat.10064.jpg  cat.12314.jpg  cat.3317.jpg  cat.5567.jpg  cat.7814.jpg
# cat.10065.jpg  cat.12315.jpg  cat.3318.jpg  cat.5568.jpg  cat.7815.jpg
# cat.10066.jpg  cat.12316.jpg  cat.3319.jpg  cat.5569.jpg  cat.7816.jpg
# cat.10067.jpg  cat.12317.jpg  cat.331.jpg   cat.556.jpg   cat.7817.jpg
# cat.10068.jpg  cat.12318.jpg  cat.3320.jpg  cat.5570.jpg  cat.7818.jpg
# cat.10069.jpg  cat.12319.jpg  cat.3321.jpg  cat.5571.jpg  cat.781.jpg
# cat.1006.jpg   cat.1231.jpg   cat.3322.jpg  cat.5572.jpg  cat.7820.jpg
# cat.10070.jpg  cat.12320.jpg  cat.3323.jpg  cat.5573.jpg  cat.7821.jpg
# cat.10071.jpg  cat.12321.jpg  cat.3324.jpg  cat.5574.jpg  cat.7822.jpg
# cat.10072.jpg  cat.12322.jpg  cat.3325.jpg  cat.5575.jpg  cat.7823.jpg
# cat.10073.jpg  cat.12323.jpg  cat.3326.jpg  cat.5576.jpg  cat.7824.jpg
# cat.10074.jpg  cat.12324.jpg  cat.3329.jpg  cat.5577.jpg  cat.7825.jpg
# cat.10075.jpg  cat.12325.jpg  cat.332.jpg   cat.5578.jpg  cat.7826.jpg
# cat.10076.jpg  cat.12326.jpg  cat.3330.jpg  cat.5579.jpg  cat.7827.jpg
# cat.10077.jpg  cat.12328.jpg  cat.3331.jpg  cat.557.jpg   cat.7828.jpg
# cat.10078.jpg  cat.12329.jpg  cat.3332.jpg  cat.5580.jpg  cat.7829.jpg
# cat.10079.jpg  cat.1232.jpg   cat.3333.jpg  cat.5581.jpg  cat.782.jpg
# cat.1007.jpg   cat.12330.jpg  cat.3335.jpg  cat.5582.jpg  cat.7830.jpg
# cat.10081.jpg  cat.12331.jpg  cat.3336.jpg  cat.5583.jpg  cat.7831.jpg
# cat.10082.jpg  cat.12332.jpg  cat.3337.jpg  cat.5584.jpg  cat.7832.jpg
# cat.10083.jpg  cat.12333.jpg  cat.3338.jpg  cat.5585.jpg  cat.7833.jpg
# cat.10084.jpg  cat.12335.jpg  cat.3339.jpg  cat.5587.jpg  cat.7834.jpg
# cat.10085.jpg  cat.12336.jpg  cat.333.jpg   cat.5588.jpg  cat.7835.jpg
# cat.10086.jpg  cat.12337.jpg  cat.3341.jpg  cat.5589.jpg  cat.7836.jpg
# cat.10087.jpg  cat.12338.jpg  cat.3343.jpg  cat.5590.jpg  cat.7838.jpg
# cat.10088.jpg  cat.12339.jpg  cat.3345.jpg  cat.5591.jpg  cat.7839.jpg
# cat.10089.jpg  cat.1233.jpg   cat.3346.jpg  cat.5592.jpg  cat.783.jpg
# cat.1008.jpg   cat.12341.jpg  cat.3347.jpg  cat.5593.jpg  cat.7840.jpg
# cat.10090.jpg  cat.12342.jpg  cat.3348.jpg  cat.5594.jpg  cat.7841.jpg
# cat.10091.jpg  cat.12343.jpg  cat.334.jpg   cat.5595.jpg  cat.7842.jpg
# cat.10092.jpg  cat.12344.jpg  cat.3350.jpg  cat.5596.jpg  cat.7843.jpg
# cat.10093.jpg  cat.12345.jpg  cat.3351.jpg  cat.5597.jpg  cat.7844.jpg
# cat.10094.jpg  cat.12346.jpg  cat.3352.jpg  cat.5598.jpg  cat.7845.jpg
# cat.10095.jpg  cat.12347.jpg  cat.3353.jpg  cat.5599.jpg  cat.7846.jpg
# cat.10096.jpg  cat.12348.jpg  cat.3354.jpg  cat.559.jpg   cat.7847.jpg
# cat.10097.jpg  cat.12349.jpg  cat.3355.jpg  cat.55.jpg	  cat.7848.jpg
# cat.10099.jpg  cat.1234.jpg   cat.3356.jpg  cat.5600.jpg  cat.7849.jpg
# cat.1009.jpg   cat.12350.jpg  cat.3357.jpg  cat.5601.jpg  cat.784.jpg
# cat.100.jpg    cat.12351.jpg  cat.3358.jpg  cat.5602.jpg  cat.7850.jpg
# cat.10100.jpg  cat.12352.jpg  cat.3359.jpg  cat.5603.jpg  cat.7851.jpg
# cat.10101.jpg  cat.12353.jpg  cat.335.jpg   cat.5604.jpg  cat.7852.jpg
# cat.10102.jpg  cat.12354.jpg  cat.3360.jpg  cat.5605.jpg  cat.7853.jpg
# cat.10103.jpg  cat.12355.jpg  cat.3361.jpg  cat.5606.jpg  cat.7854.jpg
# cat.10105.jpg  cat.12356.jpg  cat.3362.jpg  cat.5607.jpg  cat.7855.jpg
# cat.10106.jpg  cat.12357.jpg  cat.3363.jpg  cat.5608.jpg  cat.7856.jpg
# cat.10107.jpg  cat.12358.jpg  cat.3364.jpg  cat.5609.jpg  cat.7857.jpg
# cat.10108.jpg  cat.12359.jpg  cat.3365.jpg  cat.560.jpg   cat.7858.jpg
# cat.10109.jpg  cat.1235.jpg   cat.3366.jpg  cat.5610.jpg  cat.7859.jpg
# cat.1010.jpg   cat.12360.jpg  cat.3368.jpg  cat.5611.jpg  cat.785.jpg
# cat.10110.jpg  cat.12361.jpg  cat.3369.jpg  cat.5612.jpg  cat.7860.jpg
# cat.10111.jpg  cat.12362.jpg  cat.336.jpg   cat.5613.jpg  cat.7861.jpg
# cat.10112.jpg  cat.12363.jpg  cat.3370.jpg  cat.5614.jpg  cat.7862.jpg
# cat.10114.jpg  cat.12365.jpg  cat.3371.jpg  cat.5615.jpg  cat.7863.jpg
# cat.10115.jpg  cat.12366.jpg  cat.3372.jpg  cat.5616.jpg  cat.7864.jpg
# cat.10116.jpg  cat.12367.jpg  cat.3373.jpg  cat.5617.jpg  cat.7866.jpg
# cat.10117.jpg  cat.12368.jpg  cat.3374.jpg  cat.5618.jpg  cat.7867.jpg
# cat.10118.jpg  cat.12369.jpg  cat.3375.jpg  cat.5619.jpg  cat.7869.jpg
# cat.10119.jpg  cat.1236.jpg   cat.3376.jpg  cat.561.jpg   cat.786.jpg
# cat.1011.jpg   cat.12370.jpg  cat.3377.jpg  cat.5620.jpg  cat.7871.jpg
# cat.10120.jpg  cat.12371.jpg  cat.3378.jpg  cat.5621.jpg  cat.7872.jpg
# cat.10121.jpg  cat.12372.jpg  cat.3379.jpg  cat.5622.jpg  cat.7873.jpg
# cat.10122.jpg  cat.12373.jpg  cat.337.jpg   cat.5623.jpg  cat.7874.jpg
# cat.10123.jpg  cat.12374.jpg  cat.3380.jpg  cat.5624.jpg  cat.7876.jpg
# cat.10124.jpg  cat.12375.jpg  cat.3381.jpg  cat.5625.jpg  cat.7877.jpg
# cat.10125.jpg  cat.12376.jpg  cat.3382.jpg  cat.5626.jpg  cat.7878.jpg
# cat.10126.jpg  cat.12377.jpg  cat.3383.jpg  cat.5627.jpg  cat.7879.jpg
# cat.10127.jpg  cat.12379.jpg  cat.3384.jpg  cat.5628.jpg  cat.787.jpg
# cat.10128.jpg  cat.1237.jpg   cat.3385.jpg  cat.5629.jpg  cat.7880.jpg
# cat.10129.jpg  cat.12380.jpg  cat.3386.jpg  cat.562.jpg   cat.7881.jpg
# cat.1012.jpg   cat.12381.jpg  cat.3387.jpg  cat.5630.jpg  cat.7882.jpg
# cat.10130.jpg  cat.12382.jpg  cat.3388.jpg  cat.5631.jpg  cat.7883.jpg
# cat.10132.jpg  cat.12383.jpg  cat.3389.jpg  cat.5632.jpg  cat.7885.jpg
# cat.10133.jpg  cat.12384.jpg  cat.338.jpg   cat.5634.jpg  cat.7886.jpg
# cat.10134.jpg  cat.12386.jpg  cat.3390.jpg  cat.5635.jpg  cat.7887.jpg
# cat.10136.jpg  cat.12387.jpg  cat.3391.jpg  cat.5636.jpg  cat.7888.jpg
# cat.10137.jpg  cat.12389.jpg  cat.3392.jpg  cat.5637.jpg  cat.7889.jpg
# cat.10138.jpg  cat.1238.jpg   cat.3393.jpg  cat.5638.jpg  cat.7890.jpg
# cat.10139.jpg  cat.12390.jpg  cat.3394.jpg  cat.5639.jpg  cat.7891.jpg
# cat.10140.jpg  cat.12391.jpg  cat.3396.jpg  cat.563.jpg   cat.7892.jpg
# cat.10141.jpg  cat.12392.jpg  cat.3397.jpg  cat.5640.jpg  cat.7893.jpg
# cat.10142.jpg  cat.12393.jpg  cat.3398.jpg  cat.5641.jpg  cat.7895.jpg
# cat.10143.jpg  cat.12394.jpg  cat.3399.jpg  cat.5643.jpg  cat.7896.jpg
# cat.10144.jpg  cat.12395.jpg  cat.33.jpg    cat.5644.jpg  cat.7897.jpg
# cat.10145.jpg  cat.12396.jpg  cat.3400.jpg  cat.5645.jpg  cat.7898.jpg
# cat.10146.jpg  cat.12397.jpg  cat.3401.jpg  cat.5646.jpg  cat.7899.jpg
# cat.10147.jpg  cat.12398.jpg  cat.3402.jpg  cat.5648.jpg  cat.789.jpg
# cat.10148.jpg  cat.12399.jpg  cat.3403.jpg  cat.5649.jpg  cat.78.jpg
# cat.10149.jpg  cat.1239.jpg   cat.3404.jpg  cat.564.jpg   cat.7900.jpg
# cat.1014.jpg   cat.123.jpg    cat.3405.jpg  cat.5650.jpg  cat.7901.jpg
# cat.10150.jpg  cat.12400.jpg  cat.3406.jpg  cat.5652.jpg  cat.7902.jpg
# cat.10151.jpg  cat.12401.jpg  cat.3407.jpg  cat.5653.jpg  cat.7903.jpg
# cat.10152.jpg  cat.12402.jpg  cat.3408.jpg  cat.5655.jpg  cat.7904.jpg
# cat.10153.jpg  cat.12403.jpg  cat.3409.jpg  cat.5656.jpg  cat.7905.jpg
# cat.10154.jpg  cat.12404.jpg  cat.340.jpg   cat.5657.jpg  cat.7906.jpg
# cat.10155.jpg  cat.12405.jpg  cat.3410.jpg  cat.5658.jpg  cat.7907.jpg
# cat.10156.jpg  cat.12406.jpg  cat.3411.jpg  cat.5659.jpg  cat.7908.jpg
# cat.10157.jpg  cat.12408.jpg  cat.3413.jpg  cat.565.jpg   cat.7909.jpg
# cat.10158.jpg  cat.12409.jpg  cat.3414.jpg  cat.5660.jpg  cat.790.jpg
# cat.10159.jpg  cat.1240.jpg   cat.3415.jpg  cat.5661.jpg  cat.7910.jpg
# cat.1015.jpg   cat.12410.jpg  cat.3416.jpg  cat.5662.jpg  cat.7911.jpg
# cat.10160.jpg  cat.12411.jpg  cat.3417.jpg  cat.5664.jpg  cat.7912.jpg
# cat.10161.jpg  cat.12412.jpg  cat.3418.jpg  cat.5665.jpg  cat.7914.jpg
# cat.10162.jpg  cat.12413.jpg  cat.3419.jpg  cat.5666.jpg  cat.7915.jpg
# cat.10163.jpg  cat.12414.jpg  cat.341.jpg   cat.5667.jpg  cat.7916.jpg
# cat.10164.jpg  cat.12415.jpg  cat.3420.jpg  cat.5668.jpg  cat.7917.jpg
# cat.10165.jpg  cat.12416.jpg  cat.3421.jpg  cat.5669.jpg  cat.7918.jpg
# cat.10166.jpg  cat.12417.jpg  cat.3422.jpg  cat.566.jpg   cat.7919.jpg
# cat.10167.jpg  cat.12418.jpg  cat.3423.jpg  cat.5670.jpg  cat.791.jpg
# cat.10168.jpg  cat.12419.jpg  cat.3424.jpg  cat.5671.jpg  cat.7920.jpg
# cat.10169.jpg  cat.1241.jpg   cat.3425.jpg  cat.5672.jpg  cat.7921.jpg
# cat.1016.jpg   cat.12420.jpg  cat.3426.jpg  cat.5673.jpg  cat.7922.jpg
# cat.10170.jpg  cat.12422.jpg  cat.3427.jpg  cat.5674.jpg  cat.7923.jpg
# cat.10171.jpg  cat.12423.jpg  cat.3428.jpg  cat.5675.jpg  cat.7924.jpg
# cat.10172.jpg  cat.12424.jpg  cat.3429.jpg  cat.5676.jpg  cat.7925.jpg
# cat.10173.jpg  cat.12425.jpg  cat.342.jpg   cat.5677.jpg  cat.7926.jpg
# cat.10174.jpg  cat.12426.jpg  cat.3430.jpg  cat.5678.jpg  cat.7927.jpg
# cat.10175.jpg  cat.12427.jpg  cat.3432.jpg  cat.5679.jpg  cat.7928.jpg
# cat.10176.jpg  cat.12428.jpg  cat.3433.jpg  cat.5680.jpg  cat.7929.jpg
# cat.10177.jpg  cat.12429.jpg  cat.3434.jpg  cat.5681.jpg  cat.792.jpg
# cat.10178.jpg  cat.1242.jpg   cat.3435.jpg  cat.5682.jpg  cat.7930.jpg
# cat.10179.jpg  cat.12430.jpg  cat.3436.jpg  cat.5683.jpg  cat.7931.jpg
# cat.1017.jpg   cat.12431.jpg  cat.3437.jpg  cat.5684.jpg  cat.7932.jpg
# cat.10180.jpg  cat.12432.jpg  cat.3438.jpg  cat.5685.jpg  cat.7933.jpg
# cat.10181.jpg  cat.12433.jpg  cat.3439.jpg  cat.5686.jpg  cat.7934.jpg
# cat.10182.jpg  cat.12434.jpg  cat.3440.jpg  cat.5687.jpg  cat.7935.jpg
# cat.10183.jpg  cat.12435.jpg  cat.3441.jpg  cat.5688.jpg  cat.7936.jpg
# cat.10184.jpg  cat.12436.jpg  cat.3442.jpg  cat.5689.jpg  cat.7938.jpg
# cat.10185.jpg  cat.12437.jpg  cat.3443.jpg  cat.568.jpg   cat.7939.jpg
# cat.10186.jpg  cat.12438.jpg  cat.3444.jpg  cat.5690.jpg  cat.793.jpg
# cat.10187.jpg  cat.12439.jpg  cat.3445.jpg  cat.5691.jpg  cat.7940.jpg
# cat.10188.jpg  cat.1243.jpg   cat.3446.jpg  cat.5692.jpg  cat.7941.jpg
# cat.10189.jpg  cat.12440.jpg  cat.3447.jpg  cat.5693.jpg  cat.7942.jpg
# cat.1018.jpg   cat.12441.jpg  cat.3448.jpg  cat.5696.jpg  cat.7943.jpg
# cat.10190.jpg  cat.12442.jpg  cat.3449.jpg  cat.5697.jpg  cat.7944.jpg
# cat.10191.jpg  cat.12443.jpg  cat.344.jpg   cat.5698.jpg  cat.7945.jpg
# cat.10192.jpg  cat.12444.jpg  cat.3450.jpg  cat.5699.jpg  cat.7946.jpg
# cat.10193.jpg  cat.12445.jpg  cat.3451.jpg  cat.569.jpg   cat.7947.jpg
# cat.10194.jpg  cat.12446.jpg  cat.3452.jpg  cat.5700.jpg  cat.7948.jpg
# cat.10195.jpg  cat.12447.jpg  cat.3453.jpg  cat.5701.jpg  cat.7949.jpg
# cat.10196.jpg  cat.12448.jpg  cat.3454.jpg  cat.5702.jpg  cat.794.jpg
# cat.10197.jpg  cat.12449.jpg  cat.3455.jpg  cat.5703.jpg  cat.7951.jpg
# cat.10198.jpg  cat.12450.jpg  cat.3456.jpg  cat.5704.jpg  cat.7952.jpg
# cat.10199.jpg  cat.12451.jpg  cat.3457.jpg  cat.5705.jpg  cat.7953.jpg
# cat.1019.jpg   cat.12452.jpg  cat.3458.jpg  cat.5706.jpg  cat.7954.jpg
# cat.101.jpg    cat.12453.jpg  cat.3459.jpg  cat.5707.jpg  cat.7955.jpg
# cat.10200.jpg  cat.12454.jpg  cat.3460.jpg  cat.5708.jpg  cat.7956.jpg
# cat.10201.jpg  cat.12455.jpg  cat.3461.jpg  cat.5709.jpg  cat.7957.jpg
# cat.10202.jpg  cat.12456.jpg  cat.3462.jpg  cat.570.jpg   cat.7958.jpg
# cat.10203.jpg  cat.12457.jpg  cat.3463.jpg  cat.5710.jpg  cat.7959.jpg
# cat.10204.jpg  cat.12458.jpg  cat.3464.jpg  cat.5711.jpg  cat.795.jpg
# cat.10205.jpg  cat.12459.jpg  cat.3465.jpg  cat.5712.jpg  cat.7960.jpg
# cat.10207.jpg  cat.12460.jpg  cat.3466.jpg  cat.5713.jpg  cat.7961.jpg
# cat.10208.jpg  cat.12461.jpg  cat.3467.jpg  cat.5714.jpg  cat.7962.jpg
# cat.10209.jpg  cat.12462.jpg  cat.3468.jpg  cat.5715.jpg  cat.7963.jpg
# cat.1020.jpg   cat.12463.jpg  cat.3469.jpg  cat.5716.jpg  cat.7964.jpg
# cat.10210.jpg  cat.12464.jpg  cat.346.jpg   cat.5717.jpg  cat.7965.jpg
# cat.10211.jpg  cat.12465.jpg  cat.3470.jpg  cat.5719.jpg  cat.7967.jpg
# cat.10212.jpg  cat.12466.jpg  cat.3471.jpg  cat.571.jpg   cat.7968.jpg
# cat.10213.jpg  cat.12467.jpg  cat.3472.jpg  cat.5720.jpg  cat.7969.jpg
# cat.10214.jpg  cat.12468.jpg  cat.3473.jpg  cat.5721.jpg  cat.796.jpg
# cat.10215.jpg  cat.12469.jpg  cat.3474.jpg  cat.5722.jpg  cat.7971.jpg
# cat.10216.jpg  cat.12470.jpg  cat.3476.jpg  cat.5724.jpg  cat.7972.jpg
# cat.10217.jpg  cat.12471.jpg  cat.3477.jpg  cat.5725.jpg  cat.7974.jpg
# cat.10218.jpg  cat.12472.jpg  cat.3478.jpg  cat.5726.jpg  cat.7975.jpg
# cat.10219.jpg  cat.12473.jpg  cat.3479.jpg  cat.5727.jpg  cat.7976.jpg
# cat.1021.jpg   cat.12474.jpg  cat.347.jpg   cat.5728.jpg  cat.7978.jpg
# cat.10220.jpg  cat.12475.jpg  cat.3480.jpg  cat.5729.jpg  cat.7979.jpg
# cat.10221.jpg  cat.12476.jpg  cat.3481.jpg  cat.572.jpg   cat.797.jpg
# cat.10222.jpg  cat.12478.jpg  cat.3482.jpg  cat.5730.jpg  cat.7980.jpg
# cat.10223.jpg  cat.12479.jpg  cat.3483.jpg  cat.5731.jpg  cat.7981.jpg
# cat.10224.jpg  cat.1247.jpg   cat.3484.jpg  cat.5732.jpg  cat.7982.jpg
# cat.10225.jpg  cat.12480.jpg  cat.3485.jpg  cat.5733.jpg  cat.7983.jpg
# cat.10226.jpg  cat.12481.jpg  cat.3486.jpg  cat.5734.jpg  cat.7984.jpg
# cat.10227.jpg  cat.12482.jpg  cat.3487.jpg  cat.5735.jpg  cat.7985.jpg
# cat.10228.jpg  cat.12483.jpg  cat.3488.jpg  cat.5736.jpg  cat.7986.jpg
# cat.10229.jpg  cat.12484.jpg  cat.3489.jpg  cat.5737.jpg  cat.7987.jpg
# cat.1022.jpg   cat.12485.jpg  cat.348.jpg   cat.5738.jpg  cat.7988.jpg
# cat.10230.jpg  cat.12486.jpg  cat.3490.jpg  cat.5739.jpg  cat.7989.jpg
# cat.10231.jpg  cat.12488.jpg  cat.3491.jpg  cat.573.jpg   cat.798.jpg
# cat.10232.jpg  cat.12489.jpg  cat.3492.jpg  cat.5740.jpg  cat.7990.jpg
# cat.10233.jpg  cat.1248.jpg   cat.3493.jpg  cat.5741.jpg  cat.7991.jpg
# cat.10234.jpg  cat.12490.jpg  cat.3494.jpg  cat.5742.jpg  cat.7992.jpg
# cat.10235.jpg  cat.12491.jpg  cat.3495.jpg  cat.5743.jpg  cat.7993.jpg
# cat.10236.jpg  cat.12492.jpg  cat.3496.jpg  cat.5744.jpg  cat.7994.jpg
# cat.10237.jpg  cat.12493.jpg  cat.3497.jpg  cat.5745.jpg  cat.7995.jpg
# cat.10238.jpg  cat.12494.jpg  cat.3498.jpg  cat.5746.jpg  cat.7996.jpg
# cat.10239.jpg  cat.12495.jpg  cat.3499.jpg  cat.5747.jpg  cat.7997.jpg
# cat.10240.jpg  cat.12496.jpg  cat.349.jpg   cat.5748.jpg  cat.7998.jpg
# cat.10241.jpg  cat.12497.jpg  cat.34.jpg    cat.5749.jpg  cat.7999.jpg
# cat.10242.jpg  cat.12498.jpg  cat.3500.jpg  cat.574.jpg   cat.799.jpg
# cat.10243.jpg  cat.12499.jpg  cat.3501.jpg  cat.5750.jpg  cat.79.jpg
# cat.10244.jpg  cat.1249.jpg   cat.3502.jpg  cat.5751.jpg  cat.7.jpg
# cat.10245.jpg  cat.124.jpg    cat.3503.jpg  cat.5752.jpg  cat.8000.jpg
# cat.10246.jpg  cat.1250.jpg   cat.3504.jpg  cat.5753.jpg  cat.8001.jpg
# cat.10247.jpg  cat.1251.jpg   cat.3505.jpg  cat.5754.jpg  cat.8002.jpg
# cat.10248.jpg  cat.1252.jpg   cat.3506.jpg  cat.5755.jpg  cat.8003.jpg
# cat.10249.jpg  cat.1253.jpg   cat.3507.jpg  cat.5757.jpg  cat.8004.jpg
# cat.1024.jpg   cat.1254.jpg   cat.3508.jpg  cat.5758.jpg  cat.8005.jpg
# cat.10250.jpg  cat.1255.jpg   cat.3509.jpg  cat.5759.jpg  cat.8006.jpg
# cat.10251.jpg  cat.1256.jpg   cat.350.jpg   cat.575.jpg   cat.8007.jpg
# cat.10252.jpg  cat.1257.jpg   cat.3510.jpg  cat.5760.jpg  cat.8008.jpg
# cat.10253.jpg  cat.1258.jpg   cat.3511.jpg  cat.5761.jpg  cat.8009.jpg
# cat.10254.jpg  cat.1259.jpg   cat.3512.jpg  cat.5763.jpg  cat.8010.jpg
# cat.10255.jpg  cat.125.jpg    cat.3513.jpg  cat.5764.jpg  cat.8011.jpg
# cat.10257.jpg  cat.1260.jpg   cat.3514.jpg  cat.5766.jpg  cat.8012.jpg
# cat.10258.jpg  cat.1261.jpg   cat.3515.jpg  cat.5767.jpg  cat.8013.jpg
# cat.10259.jpg  cat.1262.jpg   cat.3516.jpg  cat.5769.jpg  cat.8014.jpg
# cat.1025.jpg   cat.1263.jpg   cat.3517.jpg  cat.576.jpg   cat.8015.jpg
# cat.10260.jpg  cat.1264.jpg   cat.3518.jpg  cat.5772.jpg  cat.8016.jpg
# cat.10261.jpg  cat.1265.jpg   cat.3519.jpg  cat.5773.jpg  cat.8017.jpg
# cat.10262.jpg  cat.1266.jpg   cat.351.jpg   cat.5774.jpg  cat.8018.jpg
# cat.10263.jpg  cat.1267.jpg   cat.3520.jpg  cat.5775.jpg  cat.8019.jpg
# cat.10264.jpg  cat.1268.jpg   cat.3521.jpg  cat.5776.jpg  cat.801.jpg
# cat.10265.jpg  cat.1269.jpg   cat.3522.jpg  cat.5777.jpg  cat.8020.jpg
# cat.10266.jpg  cat.126.jpg    cat.3523.jpg  cat.5778.jpg  cat.8021.jpg
# cat.10267.jpg  cat.1270.jpg   cat.3524.jpg  cat.5779.jpg  cat.8022.jpg
# cat.10268.jpg  cat.1271.jpg   cat.3525.jpg  cat.577.jpg   cat.8023.jpg
# cat.10269.jpg  cat.1272.jpg   cat.3526.jpg  cat.5780.jpg  cat.8024.jpg
# cat.1026.jpg   cat.1273.jpg   cat.3527.jpg  cat.5781.jpg  cat.8025.jpg
# cat.10271.jpg  cat.1274.jpg   cat.3528.jpg  cat.5782.jpg  cat.8026.jpg
# cat.10272.jpg  cat.1275.jpg   cat.3529.jpg  cat.5783.jpg  cat.8027.jpg
# cat.10273.jpg  cat.1276.jpg   cat.352.jpg   cat.5784.jpg  cat.8029.jpg
# cat.10274.jpg  cat.1277.jpg   cat.3530.jpg  cat.5786.jpg  cat.802.jpg
# cat.10275.jpg  cat.1278.jpg   cat.3531.jpg  cat.5787.jpg  cat.8030.jpg
# cat.10276.jpg  cat.1279.jpg   cat.3532.jpg  cat.5788.jpg  cat.8031.jpg
# cat.10277.jpg  cat.127.jpg    cat.3533.jpg  cat.5789.jpg  cat.8032.jpg
# cat.10278.jpg  cat.1280.jpg   cat.3534.jpg  cat.578.jpg   cat.8033.jpg
# cat.10279.jpg  cat.1281.jpg   cat.3535.jpg  cat.5790.jpg  cat.8034.jpg
# cat.1027.jpg   cat.1282.jpg   cat.3536.jpg  cat.5791.jpg  cat.8035.jpg
# cat.10280.jpg  cat.1283.jpg   cat.3537.jpg  cat.5792.jpg  cat.8036.jpg
# cat.10281.jpg  cat.1284.jpg   cat.3538.jpg  cat.5793.jpg  cat.8037.jpg
# cat.10282.jpg  cat.1285.jpg   cat.3539.jpg  cat.5794.jpg  cat.8038.jpg
# cat.10283.jpg  cat.1287.jpg   cat.353.jpg   cat.5795.jpg  cat.8039.jpg
# cat.10284.jpg  cat.1289.jpg   cat.3540.jpg  cat.5796.jpg  cat.803.jpg
# cat.10285.jpg  cat.128.jpg    cat.3541.jpg  cat.5797.jpg  cat.8040.jpg
# cat.10286.jpg  cat.1290.jpg   cat.3542.jpg  cat.5798.jpg  cat.8041.jpg
# cat.10287.jpg  cat.1291.jpg   cat.3543.jpg  cat.579.jpg   cat.8042.jpg
# cat.10288.jpg  cat.1292.jpg   cat.3545.jpg  cat.57.jpg	  cat.8043.jpg
# cat.10289.jpg  cat.1293.jpg   cat.3546.jpg  cat.5800.jpg  cat.8044.jpg
# cat.1028.jpg   cat.1294.jpg   cat.3547.jpg  cat.5801.jpg  cat.8045.jpg
# cat.10290.jpg  cat.1295.jpg   cat.3548.jpg  cat.5802.jpg  cat.8046.jpg
# cat.10291.jpg  cat.1296.jpg   cat.3549.jpg  cat.5803.jpg  cat.8047.jpg
# cat.10293.jpg  cat.1297.jpg   cat.354.jpg   cat.5804.jpg  cat.8048.jpg
# cat.10294.jpg  cat.1298.jpg   cat.3550.jpg  cat.5805.jpg  cat.8049.jpg
# cat.10295.jpg  cat.1299.jpg   cat.3551.jpg  cat.5806.jpg  cat.8050.jpg
# cat.10296.jpg  cat.129.jpg    cat.3552.jpg  cat.5807.jpg  cat.8051.jpg
# cat.10297.jpg  cat.12.jpg     cat.3553.jpg  cat.5808.jpg  cat.8052.jpg
# cat.10298.jpg  cat.1300.jpg   cat.3554.jpg  cat.5809.jpg  cat.8053.jpg
# cat.10299.jpg  cat.1301.jpg   cat.3555.jpg  cat.580.jpg   cat.8054.jpg
# cat.1029.jpg   cat.1302.jpg   cat.3556.jpg  cat.5810.jpg  cat.8055.jpg
# cat.102.jpg    cat.1303.jpg   cat.3557.jpg  cat.5811.jpg  cat.8056.jpg
# cat.10300.jpg  cat.1304.jpg   cat.3558.jpg  cat.5813.jpg  cat.8057.jpg
# cat.10301.jpg  cat.1305.jpg   cat.355.jpg   cat.5814.jpg  cat.8058.jpg
# cat.10303.jpg  cat.1306.jpg   cat.3560.jpg  cat.5815.jpg  cat.8059.jpg
# cat.10304.jpg  cat.1307.jpg   cat.3561.jpg  cat.5816.jpg  cat.805.jpg
# cat.10305.jpg  cat.1308.jpg   cat.3562.jpg  cat.5818.jpg  cat.8060.jpg
# cat.10306.jpg  cat.1309.jpg   cat.3563.jpg  cat.5819.jpg  cat.8061.jpg
# cat.10308.jpg  cat.130.jpg    cat.3564.jpg  cat.581.jpg   cat.8062.jpg
# cat.10309.jpg  cat.1311.jpg   cat.3565.jpg  cat.5821.jpg  cat.8063.jpg
# cat.1030.jpg   cat.1312.jpg   cat.3566.jpg  cat.5822.jpg  cat.8064.jpg
# cat.10310.jpg  cat.1313.jpg   cat.3567.jpg  cat.5823.jpg  cat.8065.jpg
# cat.10311.jpg  cat.1314.jpg   cat.3568.jpg  cat.5825.jpg  cat.8066.jpg
# cat.10312.jpg  cat.1315.jpg   cat.356.jpg   cat.5826.jpg  cat.8067.jpg
# cat.10313.jpg  cat.1316.jpg   cat.3570.jpg  cat.5827.jpg  cat.8068.jpg
# cat.10314.jpg  cat.1317.jpg   cat.3571.jpg  cat.5828.jpg  cat.806.jpg
# cat.10315.jpg  cat.1318.jpg   cat.3572.jpg  cat.5829.jpg  cat.8070.jpg
# cat.10316.jpg  cat.1319.jpg   cat.3573.jpg  cat.582.jpg   cat.8072.jpg
# cat.10317.jpg  cat.131.jpg    cat.3574.jpg  cat.5830.jpg  cat.8075.jpg
# cat.10318.jpg  cat.1320.jpg   cat.3575.jpg  cat.5831.jpg  cat.8076.jpg
# cat.10319.jpg  cat.1321.jpg   cat.3576.jpg  cat.5832.jpg  cat.8077.jpg
# cat.1031.jpg   cat.1322.jpg   cat.3577.jpg  cat.5833.jpg  cat.8078.jpg
# cat.10320.jpg  cat.1323.jpg   cat.3578.jpg  cat.5834.jpg  cat.8079.jpg
# cat.10322.jpg  cat.1324.jpg   cat.3579.jpg  cat.5835.jpg  cat.807.jpg
# cat.10323.jpg  cat.1325.jpg   cat.357.jpg   cat.5836.jpg  cat.8081.jpg
# cat.10324.jpg  cat.1326.jpg   cat.3580.jpg  cat.5837.jpg  cat.8082.jpg
# cat.10325.jpg  cat.1327.jpg   cat.3581.jpg  cat.5838.jpg  cat.8083.jpg
# cat.10326.jpg  cat.1328.jpg   cat.3582.jpg  cat.5839.jpg  cat.8084.jpg
# cat.10327.jpg  cat.1329.jpg   cat.3583.jpg  cat.583.jpg   cat.8086.jpg
# cat.10328.jpg  cat.1330.jpg   cat.3584.jpg  cat.5840.jpg  cat.8087.jpg
# cat.10329.jpg  cat.1331.jpg   cat.3585.jpg  cat.5841.jpg  cat.8088.jpg
# cat.1032.jpg   cat.1333.jpg   cat.3587.jpg  cat.5842.jpg  cat.8089.jpg
# cat.10330.jpg  cat.1334.jpg   cat.3589.jpg  cat.5843.jpg  cat.808.jpg
# cat.10331.jpg  cat.1335.jpg   cat.358.jpg   cat.5844.jpg  cat.8090.jpg
# cat.10332.jpg  cat.1336.jpg   cat.3590.jpg  cat.5845.jpg  cat.8092.jpg
# cat.10334.jpg  cat.1337.jpg   cat.3591.jpg  cat.5846.jpg  cat.8093.jpg
# cat.10335.jpg  cat.1338.jpg   cat.3592.jpg  cat.5847.jpg  cat.8094.jpg
# cat.10336.jpg  cat.1340.jpg   cat.3593.jpg  cat.5848.jpg  cat.8095.jpg
# cat.10337.jpg  cat.1341.jpg   cat.3594.jpg  cat.5849.jpg  cat.8096.jpg
# cat.10339.jpg  cat.1342.jpg   cat.3595.jpg  cat.584.jpg   cat.8097.jpg
# cat.1033.jpg   cat.1343.jpg   cat.3596.jpg  cat.5850.jpg  cat.8098.jpg
# cat.10340.jpg  cat.1344.jpg   cat.3597.jpg  cat.5851.jpg  cat.8099.jpg
# cat.10341.jpg  cat.1345.jpg   cat.3598.jpg  cat.5853.jpg  cat.809.jpg
# cat.10342.jpg  cat.1347.jpg   cat.3599.jpg  cat.5854.jpg  cat.80.jpg
# cat.10343.jpg  cat.1348.jpg   cat.359.jpg   cat.5855.jpg  cat.8100.jpg
# cat.10344.jpg  cat.1349.jpg   cat.35.jpg    cat.5856.jpg  cat.8101.jpg
# cat.10345.jpg  cat.134.jpg    cat.3600.jpg  cat.5857.jpg  cat.8102.jpg
# cat.10346.jpg  cat.1350.jpg   cat.3601.jpg  cat.5858.jpg  cat.8103.jpg
# cat.10348.jpg  cat.1351.jpg   cat.3602.jpg  cat.5859.jpg  cat.8104.jpg
# cat.10349.jpg  cat.1352.jpg   cat.3603.jpg  cat.585.jpg   cat.8106.jpg
# cat.1034.jpg   cat.1353.jpg   cat.3604.jpg  cat.5860.jpg  cat.8107.jpg
# cat.10350.jpg  cat.1354.jpg   cat.3605.jpg  cat.5863.jpg  cat.8109.jpg
# cat.10351.jpg  cat.1355.jpg   cat.3606.jpg  cat.5864.jpg  cat.810.jpg
# cat.10352.jpg  cat.1357.jpg   cat.3607.jpg  cat.5866.jpg  cat.8110.jpg
# cat.10353.jpg  cat.1358.jpg   cat.3608.jpg  cat.5867.jpg  cat.8111.jpg
# cat.10354.jpg  cat.1359.jpg   cat.3609.jpg  cat.5868.jpg  cat.8112.jpg
# cat.10355.jpg  cat.135.jpg    cat.360.jpg   cat.5869.jpg  cat.8113.jpg
# cat.10356.jpg  cat.1360.jpg   cat.3610.jpg  cat.586.jpg   cat.8114.jpg
# cat.10357.jpg  cat.1362.jpg   cat.3611.jpg  cat.5871.jpg  cat.8115.jpg
# cat.10358.jpg  cat.1363.jpg   cat.3612.jpg  cat.5872.jpg  cat.8116.jpg
# cat.10359.jpg  cat.1364.jpg   cat.3613.jpg  cat.5873.jpg  cat.8117.jpg
# cat.1035.jpg   cat.1365.jpg   cat.3614.jpg  cat.5874.jpg  cat.8118.jpg
# cat.10360.jpg  cat.1366.jpg   cat.3615.jpg  cat.5875.jpg  cat.8119.jpg
# cat.10361.jpg  cat.1367.jpg   cat.3616.jpg  cat.5876.jpg  cat.811.jpg
# cat.10362.jpg  cat.1368.jpg   cat.3617.jpg  cat.5877.jpg  cat.8120.jpg
# cat.10363.jpg  cat.1369.jpg   cat.3618.jpg  cat.5878.jpg  cat.8121.jpg
# cat.10364.jpg  cat.136.jpg    cat.3619.jpg  cat.5879.jpg  cat.8122.jpg
# cat.10365.jpg  cat.1370.jpg   cat.3620.jpg  cat.587.jpg   cat.8123.jpg
# cat.10366.jpg  cat.1371.jpg   cat.3621.jpg  cat.5880.jpg  cat.8124.jpg
# cat.10367.jpg  cat.1373.jpg   cat.3622.jpg  cat.5881.jpg  cat.8125.jpg
# cat.10368.jpg  cat.1374.jpg   cat.3624.jpg  cat.5882.jpg  cat.8126.jpg
# cat.10369.jpg  cat.1375.jpg   cat.3625.jpg  cat.5883.jpg  cat.8127.jpg
# cat.1036.jpg   cat.1376.jpg   cat.3626.jpg  cat.5884.jpg  cat.8128.jpg
# cat.10370.jpg  cat.1377.jpg   cat.3627.jpg  cat.5885.jpg  cat.812.jpg
# cat.10371.jpg  cat.1378.jpg   cat.3628.jpg  cat.5886.jpg  cat.8130.jpg
# cat.10372.jpg  cat.1379.jpg   cat.362.jpg   cat.5887.jpg  cat.8131.jpg
# cat.10373.jpg  cat.137.jpg    cat.3630.jpg  cat.5888.jpg  cat.8132.jpg
# cat.10375.jpg  cat.1380.jpg   cat.3631.jpg  cat.5889.jpg  cat.8133.jpg
# cat.10376.jpg  cat.1381.jpg   cat.3632.jpg  cat.588.jpg   cat.8134.jpg
# cat.10377.jpg  cat.1383.jpg   cat.3633.jpg  cat.5890.jpg  cat.8135.jpg
# cat.10378.jpg  cat.1384.jpg   cat.3634.jpg  cat.5891.jpg  cat.8136.jpg
# cat.10379.jpg  cat.1385.jpg   cat.3635.jpg  cat.5892.jpg  cat.8137.jpg
# cat.1037.jpg   cat.1386.jpg   cat.3637.jpg  cat.5893.jpg  cat.8138.jpg
# cat.10380.jpg  cat.1387.jpg   cat.3638.jpg  cat.5894.jpg  cat.8139.jpg
# cat.10381.jpg  cat.1389.jpg   cat.3639.jpg  cat.5895.jpg  cat.813.jpg
# cat.10382.jpg  cat.138.jpg    cat.363.jpg   cat.5896.jpg  cat.8140.jpg
# cat.10383.jpg  cat.1390.jpg   cat.3641.jpg  cat.5897.jpg  cat.8141.jpg
# cat.10384.jpg  cat.1391.jpg   cat.3642.jpg  cat.5898.jpg  cat.8142.jpg
# cat.10386.jpg  cat.1392.jpg   cat.3643.jpg  cat.5899.jpg  cat.8143.jpg
# cat.10387.jpg  cat.1393.jpg   cat.3644.jpg  cat.589.jpg   cat.8144.jpg
# cat.10388.jpg  cat.1395.jpg   cat.3645.jpg  cat.58.jpg	  cat.8145.jpg
# cat.10389.jpg  cat.1396.jpg   cat.3646.jpg  cat.5901.jpg  cat.8146.jpg
# cat.1038.jpg   cat.1397.jpg   cat.3647.jpg  cat.5902.jpg  cat.8147.jpg
# cat.10390.jpg  cat.1398.jpg   cat.3648.jpg  cat.5903.jpg  cat.8148.jpg
# cat.10391.jpg  cat.1399.jpg   cat.3649.jpg  cat.5904.jpg  cat.814.jpg
# cat.10393.jpg  cat.139.jpg    cat.364.jpg   cat.5905.jpg  cat.8150.jpg
# cat.10394.jpg  cat.1401.jpg   cat.3650.jpg  cat.5906.jpg  cat.8151.jpg
# cat.10395.jpg  cat.1402.jpg   cat.3651.jpg  cat.5907.jpg  cat.8152.jpg
# cat.10396.jpg  cat.1403.jpg   cat.3652.jpg  cat.5908.jpg  cat.8153.jpg
# cat.10397.jpg  cat.1404.jpg   cat.3653.jpg  cat.5909.jpg  cat.8154.jpg
# cat.10398.jpg  cat.1405.jpg   cat.3654.jpg  cat.5910.jpg  cat.8155.jpg
# cat.10399.jpg  cat.1406.jpg   cat.3655.jpg  cat.5911.jpg  cat.8157.jpg
# cat.1039.jpg   cat.1407.jpg   cat.3656.jpg  cat.5912.jpg  cat.8158.jpg
# cat.103.jpg    cat.1408.jpg   cat.3657.jpg  cat.5913.jpg  cat.8159.jpg
# cat.10400.jpg  cat.1409.jpg   cat.3658.jpg  cat.5914.jpg  cat.815.jpg
# cat.10401.jpg  cat.140.jpg    cat.3659.jpg  cat.5915.jpg  cat.8160.jpg
# cat.10403.jpg  cat.1410.jpg   cat.365.jpg   cat.5916.jpg  cat.8161.jpg
# cat.10404.jpg  cat.1411.jpg   cat.3660.jpg  cat.5918.jpg  cat.8162.jpg
# cat.10405.jpg  cat.1412.jpg   cat.3662.jpg  cat.5919.jpg  cat.8164.jpg
# cat.10406.jpg  cat.1413.jpg   cat.3663.jpg  cat.591.jpg   cat.8165.jpg
# cat.10407.jpg  cat.1414.jpg   cat.3664.jpg  cat.5920.jpg  cat.8166.jpg
# cat.10408.jpg  cat.1415.jpg   cat.3665.jpg  cat.5921.jpg  cat.8167.jpg
# cat.10409.jpg  cat.1416.jpg   cat.3666.jpg  cat.5922.jpg  cat.8168.jpg
# cat.1040.jpg   cat.1417.jpg   cat.3667.jpg  cat.5923.jpg  cat.8169.jpg
# cat.10410.jpg  cat.1418.jpg   cat.3668.jpg  cat.5924.jpg  cat.816.jpg
# cat.10411.jpg  cat.141.jpg    cat.3669.jpg  cat.5925.jpg  cat.8170.jpg
# cat.10412.jpg  cat.1420.jpg   cat.366.jpg   cat.5926.jpg  cat.8171.jpg
# cat.10413.jpg  cat.1421.jpg   cat.3670.jpg  cat.5927.jpg  cat.8172.jpg
# cat.10414.jpg  cat.1422.jpg   cat.3671.jpg  cat.5928.jpg  cat.8173.jpg
# cat.10415.jpg  cat.1423.jpg   cat.3672.jpg  cat.5929.jpg  cat.8174.jpg
# cat.10416.jpg  cat.1424.jpg   cat.3673.jpg  cat.592.jpg   cat.8175.jpg
# cat.10417.jpg  cat.1425.jpg   cat.3674.jpg  cat.5930.jpg  cat.8176.jpg
# cat.10418.jpg  cat.1426.jpg   cat.3675.jpg  cat.5931.jpg  cat.8177.jpg
# cat.10419.jpg  cat.1427.jpg   cat.3676.jpg  cat.5933.jpg  cat.8178.jpg
# cat.1041.jpg   cat.1428.jpg   cat.3677.jpg  cat.5934.jpg  cat.8179.jpg
# cat.10420.jpg  cat.1429.jpg   cat.3678.jpg  cat.5935.jpg  cat.817.jpg
# cat.10421.jpg  cat.142.jpg    cat.3679.jpg  cat.5936.jpg  cat.8181.jpg
# cat.10422.jpg  cat.1430.jpg   cat.367.jpg   cat.5937.jpg  cat.8182.jpg
# cat.10423.jpg  cat.1431.jpg   cat.3681.jpg  cat.5938.jpg  cat.8183.jpg
# cat.10424.jpg  cat.1432.jpg   cat.3682.jpg  cat.5939.jpg  cat.8184.jpg
# cat.10425.jpg  cat.1433.jpg   cat.3683.jpg  cat.593.jpg   cat.8185.jpg
# cat.10426.jpg  cat.1434.jpg   cat.3684.jpg  cat.5940.jpg  cat.8186.jpg
# cat.10427.jpg  cat.1436.jpg   cat.3685.jpg  cat.5941.jpg  cat.8187.jpg
# cat.10428.jpg  cat.1437.jpg   cat.3686.jpg  cat.5942.jpg  cat.8188.jpg
# cat.10429.jpg  cat.1438.jpg   cat.3687.jpg  cat.5943.jpg  cat.8189.jpg
# cat.1042.jpg   cat.1439.jpg   cat.3689.jpg  cat.5944.jpg  cat.818.jpg
# cat.10430.jpg  cat.143.jpg    cat.3690.jpg  cat.5946.jpg  cat.8190.jpg
# cat.10431.jpg  cat.1440.jpg   cat.3691.jpg  cat.5947.jpg  cat.8191.jpg
# cat.10432.jpg  cat.1441.jpg   cat.3693.jpg  cat.5948.jpg  cat.8192.jpg
# cat.10433.jpg  cat.1443.jpg   cat.3694.jpg  cat.5949.jpg  cat.8193.jpg
# cat.10434.jpg  cat.1444.jpg   cat.3695.jpg  cat.594.jpg   cat.8194.jpg
# cat.10435.jpg  cat.1445.jpg   cat.3696.jpg  cat.5950.jpg  cat.8195.jpg
# cat.10436.jpg  cat.1446.jpg   cat.3698.jpg  cat.5951.jpg  cat.8196.jpg
# cat.10437.jpg  cat.1447.jpg   cat.3699.jpg  cat.5952.jpg  cat.8197.jpg
# cat.10438.jpg  cat.1448.jpg   cat.369.jpg   cat.5953.jpg  cat.8198.jpg
# cat.10439.jpg  cat.144.jpg    cat.36.jpg    cat.5954.jpg  cat.8199.jpg
# cat.1043.jpg   cat.1450.jpg   cat.3700.jpg  cat.5955.jpg  cat.819.jpg
# cat.10440.jpg  cat.1451.jpg   cat.3701.jpg  cat.5956.jpg  cat.81.jpg
# cat.10441.jpg  cat.1452.jpg   cat.3702.jpg  cat.5957.jpg  cat.8200.jpg
# cat.10443.jpg  cat.1454.jpg   cat.3704.jpg  cat.5958.jpg  cat.8201.jpg
# cat.10444.jpg  cat.1455.jpg   cat.3705.jpg  cat.5959.jpg  cat.8202.jpg
# cat.10445.jpg  cat.1456.jpg   cat.3706.jpg  cat.595.jpg   cat.8203.jpg
# cat.10446.jpg  cat.1457.jpg   cat.3707.jpg  cat.5960.jpg  cat.8204.jpg
# cat.10447.jpg  cat.1458.jpg   cat.3708.jpg  cat.5961.jpg  cat.8205.jpg
# cat.10448.jpg  cat.1459.jpg   cat.3709.jpg  cat.5962.jpg  cat.8206.jpg
# cat.10449.jpg  cat.145.jpg    cat.370.jpg   cat.5963.jpg  cat.8207.jpg
# cat.1044.jpg   cat.1461.jpg   cat.3710.jpg  cat.5964.jpg  cat.8208.jpg
# cat.10450.jpg  cat.1463.jpg   cat.3711.jpg  cat.5966.jpg  cat.8209.jpg
# cat.10451.jpg  cat.1464.jpg   cat.3712.jpg  cat.5967.jpg  cat.820.jpg
# cat.10452.jpg  cat.1465.jpg   cat.3713.jpg  cat.5969.jpg  cat.8210.jpg
# cat.10453.jpg  cat.1466.jpg   cat.3714.jpg  cat.596.jpg   cat.8211.jpg
# cat.10455.jpg  cat.1467.jpg   cat.3715.jpg  cat.5971.jpg  cat.8212.jpg
# cat.10456.jpg  cat.1468.jpg   cat.3716.jpg  cat.5972.jpg  cat.8213.jpg
# cat.10457.jpg  cat.1469.jpg   cat.3717.jpg  cat.5973.jpg  cat.8214.jpg
# cat.10458.jpg  cat.146.jpg    cat.3718.jpg  cat.5974.jpg  cat.8215.jpg
# cat.10459.jpg  cat.1470.jpg   cat.3719.jpg  cat.5975.jpg  cat.8216.jpg
# cat.1045.jpg   cat.1471.jpg   cat.371.jpg   cat.5977.jpg  cat.8217.jpg
# cat.10460.jpg  cat.1472.jpg   cat.3720.jpg  cat.5978.jpg  cat.8218.jpg
# cat.10461.jpg  cat.1473.jpg   cat.3721.jpg  cat.5979.jpg  cat.8219.jpg
# cat.10462.jpg  cat.1474.jpg   cat.3722.jpg  cat.597.jpg   cat.821.jpg
# cat.10463.jpg  cat.1475.jpg   cat.3723.jpg  cat.5980.jpg  cat.8221.jpg
# cat.10464.jpg  cat.1476.jpg   cat.3724.jpg  cat.5981.jpg  cat.8222.jpg
# cat.10465.jpg  cat.1477.jpg   cat.3725.jpg  cat.5983.jpg  cat.8223.jpg
# cat.10466.jpg  cat.1479.jpg   cat.3726.jpg  cat.5984.jpg  cat.8224.jpg
# cat.10467.jpg  cat.147.jpg    cat.3728.jpg  cat.5985.jpg  cat.8226.jpg
# cat.10468.jpg  cat.1480.jpg   cat.3729.jpg  cat.5986.jpg  cat.8227.jpg
# cat.10469.jpg  cat.1481.jpg   cat.3730.jpg  cat.5987.jpg  cat.8229.jpg
# cat.1046.jpg   cat.1482.jpg   cat.3731.jpg  cat.5988.jpg  cat.822.jpg
# cat.10470.jpg  cat.1483.jpg   cat.3732.jpg  cat.5989.jpg  cat.8230.jpg
# cat.10471.jpg  cat.1484.jpg   cat.3733.jpg  cat.598.jpg   cat.8231.jpg
# cat.10472.jpg  cat.1485.jpg   cat.3734.jpg  cat.5990.jpg  cat.8232.jpg
# cat.10475.jpg  cat.1486.jpg   cat.3735.jpg  cat.5992.jpg  cat.8233.jpg
# cat.10476.jpg  cat.1487.jpg   cat.3736.jpg  cat.5993.jpg  cat.8234.jpg
# cat.10477.jpg  cat.1488.jpg   cat.3737.jpg  cat.5994.jpg  cat.8235.jpg
# cat.10478.jpg  cat.1489.jpg   cat.3738.jpg  cat.5995.jpg  cat.8236.jpg
# cat.10479.jpg  cat.148.jpg    cat.3739.jpg  cat.5996.jpg  cat.8237.jpg
# cat.1047.jpg   cat.1490.jpg   cat.373.jpg   cat.5997.jpg  cat.8239.jpg
# cat.10480.jpg  cat.1491.jpg   cat.3740.jpg  cat.5998.jpg  cat.823.jpg
# cat.10481.jpg  cat.1492.jpg   cat.3741.jpg  cat.5999.jpg  cat.8241.jpg
# cat.10482.jpg  cat.1493.jpg   cat.3742.jpg  cat.599.jpg   cat.8242.jpg
# cat.10483.jpg  cat.1494.jpg   cat.3743.jpg  cat.59.jpg	  cat.8243.jpg
# cat.10484.jpg  cat.1495.jpg   cat.3744.jpg  cat.5.jpg	  cat.8244.jpg
# cat.10485.jpg  cat.1496.jpg   cat.3745.jpg  cat.6000.jpg  cat.8246.jpg
# cat.10486.jpg  cat.1497.jpg   cat.3747.jpg  cat.6002.jpg  cat.8247.jpg
# cat.10487.jpg  cat.1498.jpg   cat.3748.jpg  cat.6003.jpg  cat.8248.jpg
# cat.10488.jpg  cat.1499.jpg   cat.3749.jpg  cat.6004.jpg  cat.8249.jpg
# cat.10489.jpg  cat.14.jpg     cat.3750.jpg  cat.6005.jpg  cat.824.jpg
# cat.1048.jpg   cat.1500.jpg   cat.3751.jpg  cat.6006.jpg  cat.8250.jpg
# cat.10490.jpg  cat.1501.jpg   cat.3752.jpg  cat.6007.jpg  cat.8251.jpg
# cat.10491.jpg  cat.1502.jpg   cat.3753.jpg  cat.6008.jpg  cat.8252.jpg
# cat.10492.jpg  cat.1504.jpg   cat.3755.jpg  cat.6009.jpg  cat.8253.jpg
# cat.10493.jpg  cat.1505.jpg   cat.3756.jpg  cat.600.jpg   cat.8254.jpg
# cat.10494.jpg  cat.1507.jpg   cat.3757.jpg  cat.6010.jpg  cat.8255.jpg
# cat.10495.jpg  cat.1508.jpg   cat.3758.jpg  cat.6011.jpg  cat.8256.jpg
# cat.10496.jpg  cat.1509.jpg   cat.375.jpg   cat.6012.jpg  cat.8257.jpg
# cat.10498.jpg  cat.1510.jpg   cat.3760.jpg  cat.6013.jpg  cat.8258.jpg
# cat.10499.jpg  cat.1511.jpg   cat.3762.jpg  cat.6014.jpg  cat.8259.jpg
# cat.1049.jpg   cat.1512.jpg   cat.3763.jpg  cat.6015.jpg  cat.825.jpg
# cat.104.jpg    cat.1513.jpg   cat.3764.jpg  cat.6016.jpg  cat.8260.jpg
# cat.10500.jpg  cat.1514.jpg   cat.3765.jpg  cat.6017.jpg  cat.8261.jpg
# cat.10501.jpg  cat.1515.jpg   cat.3766.jpg  cat.6019.jpg  cat.8262.jpg
# cat.10502.jpg  cat.1516.jpg   cat.3767.jpg  cat.601.jpg   cat.8263.jpg
# cat.10503.jpg  cat.1517.jpg   cat.3768.jpg  cat.6020.jpg  cat.8264.jpg
# cat.10504.jpg  cat.1518.jpg   cat.3769.jpg  cat.6021.jpg  cat.8265.jpg
# cat.10505.jpg  cat.1519.jpg   cat.376.jpg   cat.6022.jpg  cat.8266.jpg
# cat.10506.jpg  cat.1520.jpg   cat.3770.jpg  cat.6023.jpg  cat.8267.jpg
# cat.10508.jpg  cat.1521.jpg   cat.3771.jpg  cat.6024.jpg  cat.8268.jpg
# cat.10509.jpg  cat.1522.jpg   cat.3772.jpg  cat.6025.jpg  cat.8269.jpg
# cat.1050.jpg   cat.1523.jpg   cat.3773.jpg  cat.6026.jpg  cat.826.jpg
# cat.10510.jpg  cat.1524.jpg   cat.3774.jpg  cat.6027.jpg  cat.8270.jpg
# cat.10511.jpg  cat.1525.jpg   cat.3775.jpg  cat.6028.jpg  cat.8271.jpg
# cat.10512.jpg  cat.1526.jpg   cat.3776.jpg  cat.6029.jpg  cat.8272.jpg
# cat.10513.jpg  cat.1527.jpg   cat.3777.jpg  cat.602.jpg   cat.8274.jpg
# cat.10515.jpg  cat.1528.jpg   cat.3778.jpg  cat.6030.jpg  cat.8275.jpg
# cat.10516.jpg  cat.1529.jpg   cat.377.jpg   cat.6031.jpg  cat.8276.jpg
# cat.10517.jpg  cat.152.jpg    cat.3780.jpg  cat.6032.jpg  cat.8277.jpg
# cat.10518.jpg  cat.1530.jpg   cat.3781.jpg  cat.6034.jpg  cat.8279.jpg
# cat.10519.jpg  cat.1531.jpg   cat.3783.jpg  cat.6035.jpg  cat.827.jpg
# cat.1051.jpg   cat.1532.jpg   cat.3784.jpg  cat.6036.jpg  cat.8280.jpg
# cat.10520.jpg  cat.1533.jpg   cat.3785.jpg  cat.6037.jpg  cat.8281.jpg
# cat.10521.jpg  cat.1534.jpg   cat.3786.jpg  cat.6038.jpg  cat.8282.jpg
# cat.10522.jpg  cat.1535.jpg   cat.3788.jpg  cat.6039.jpg  cat.8283.jpg
# cat.10523.jpg  cat.1536.jpg   cat.3789.jpg  cat.603.jpg   cat.8284.jpg
# cat.10524.jpg  cat.1537.jpg   cat.378.jpg   cat.6040.jpg  cat.8285.jpg
# cat.10525.jpg  cat.1538.jpg   cat.3790.jpg  cat.6041.jpg  cat.8286.jpg
# cat.10526.jpg  cat.1539.jpg   cat.3791.jpg  cat.6042.jpg  cat.8287.jpg
# cat.10527.jpg  cat.153.jpg    cat.3792.jpg  cat.6044.jpg  cat.8288.jpg
# cat.10528.jpg  cat.1540.jpg   cat.3794.jpg  cat.6045.jpg  cat.8289.jpg
# cat.10529.jpg  cat.1542.jpg   cat.3795.jpg  cat.6046.jpg  cat.828.jpg
# cat.1052.jpg   cat.1543.jpg   cat.3796.jpg  cat.6047.jpg  cat.8290.jpg
# cat.10530.jpg  cat.1544.jpg   cat.3797.jpg  cat.6048.jpg  cat.8291.jpg
# cat.10531.jpg  cat.1545.jpg   cat.3798.jpg  cat.6049.jpg  cat.8292.jpg
# cat.10532.jpg  cat.1546.jpg   cat.3799.jpg  cat.604.jpg   cat.8293.jpg
# cat.10533.jpg  cat.1547.jpg   cat.379.jpg   cat.6050.jpg  cat.8294.jpg
# cat.10534.jpg  cat.1548.jpg   cat.3800.jpg  cat.6051.jpg  cat.8295.jpg
# cat.10535.jpg  cat.1549.jpg   cat.3801.jpg  cat.6052.jpg  cat.8296.jpg
# cat.10536.jpg  cat.154.jpg    cat.3802.jpg  cat.6053.jpg  cat.8297.jpg
# cat.10537.jpg  cat.1550.jpg   cat.3803.jpg  cat.6054.jpg  cat.8298.jpg
# cat.10538.jpg  cat.1551.jpg   cat.3804.jpg  cat.6056.jpg  cat.8299.jpg
# cat.10539.jpg  cat.1552.jpg   cat.3805.jpg  cat.6057.jpg  cat.829.jpg
# cat.1053.jpg   cat.1553.jpg   cat.3806.jpg  cat.6058.jpg  cat.82.jpg
# cat.10540.jpg  cat.1554.jpg   cat.3807.jpg  cat.6059.jpg  cat.8300.jpg
# cat.10541.jpg  cat.1555.jpg   cat.3808.jpg  cat.6060.jpg  cat.8301.jpg
# cat.10542.jpg  cat.1556.jpg   cat.3809.jpg  cat.6061.jpg  cat.8302.jpg
# cat.10543.jpg  cat.1558.jpg   cat.380.jpg   cat.6062.jpg  cat.8303.jpg
# cat.10544.jpg  cat.1559.jpg   cat.3810.jpg  cat.6063.jpg  cat.8304.jpg
# cat.10545.jpg  cat.1560.jpg   cat.3811.jpg  cat.6064.jpg  cat.8305.jpg
# cat.10546.jpg  cat.1561.jpg   cat.3813.jpg  cat.6065.jpg  cat.8306.jpg
# cat.10547.jpg  cat.1562.jpg   cat.3814.jpg  cat.6066.jpg  cat.8307.jpg
# cat.10548.jpg  cat.1563.jpg   cat.3815.jpg  cat.6067.jpg  cat.8308.jpg
# cat.10549.jpg  cat.1564.jpg   cat.3816.jpg  cat.6068.jpg  cat.8309.jpg
# cat.1054.jpg   cat.1565.jpg   cat.3817.jpg  cat.6069.jpg  cat.830.jpg
# cat.10550.jpg  cat.1566.jpg   cat.3818.jpg  cat.606.jpg   cat.8310.jpg
# cat.10551.jpg  cat.1567.jpg   cat.3819.jpg  cat.6070.jpg  cat.8312.jpg
# cat.10552.jpg  cat.1568.jpg   cat.381.jpg   cat.6071.jpg  cat.8313.jpg
# cat.10553.jpg  cat.1569.jpg   cat.3820.jpg  cat.6072.jpg  cat.8314.jpg
# cat.10554.jpg  cat.156.jpg    cat.3821.jpg  cat.6073.jpg  cat.8315.jpg
# cat.10555.jpg  cat.1570.jpg   cat.3822.jpg  cat.6075.jpg  cat.8316.jpg
# cat.10556.jpg  cat.1571.jpg   cat.3823.jpg  cat.6076.jpg  cat.8317.jpg
# cat.10557.jpg  cat.1572.jpg   cat.3824.jpg  cat.6077.jpg  cat.8318.jpg
# cat.10558.jpg  cat.1573.jpg   cat.3825.jpg  cat.6078.jpg  cat.8319.jpg
# cat.10559.jpg  cat.1574.jpg   cat.3826.jpg  cat.6079.jpg  cat.831.jpg
# cat.1055.jpg   cat.1575.jpg   cat.3827.jpg  cat.607.jpg   cat.8320.jpg
# cat.10560.jpg  cat.1576.jpg   cat.3828.jpg  cat.6080.jpg  cat.8321.jpg
# cat.10561.jpg  cat.1577.jpg   cat.382.jpg   cat.6081.jpg  cat.8322.jpg
# cat.10562.jpg  cat.1578.jpg   cat.3830.jpg  cat.6082.jpg  cat.8323.jpg
# cat.10563.jpg  cat.1579.jpg   cat.3831.jpg  cat.6083.jpg  cat.8324.jpg
# cat.10564.jpg  cat.157.jpg    cat.3832.jpg  cat.6084.jpg  cat.8325.jpg
# cat.10566.jpg  cat.1580.jpg   cat.3833.jpg  cat.6085.jpg  cat.8326.jpg
# cat.10567.jpg  cat.1581.jpg   cat.3835.jpg  cat.6086.jpg  cat.8327.jpg
# cat.10568.jpg  cat.1582.jpg   cat.3836.jpg  cat.6087.jpg  cat.8329.jpg
# cat.10569.jpg  cat.1583.jpg   cat.3837.jpg  cat.6089.jpg  cat.832.jpg
# cat.1056.jpg   cat.1584.jpg   cat.3839.jpg  cat.6090.jpg  cat.8330.jpg
# cat.10571.jpg  cat.1586.jpg   cat.383.jpg   cat.6091.jpg  cat.8331.jpg
# cat.10572.jpg  cat.1587.jpg   cat.3840.jpg  cat.6092.jpg  cat.8332.jpg
# cat.10573.jpg  cat.1588.jpg   cat.3841.jpg  cat.6093.jpg  cat.8333.jpg
# cat.10574.jpg  cat.158.jpg    cat.3842.jpg  cat.6094.jpg  cat.8334.jpg
# cat.10575.jpg  cat.1590.jpg   cat.3843.jpg  cat.6095.jpg  cat.8335.jpg
# cat.10576.jpg  cat.1591.jpg   cat.3844.jpg  cat.6096.jpg  cat.8336.jpg
# cat.10577.jpg  cat.1592.jpg   cat.3845.jpg  cat.6097.jpg  cat.8337.jpg
# cat.10578.jpg  cat.1593.jpg   cat.3846.jpg  cat.6098.jpg  cat.8338.jpg
# cat.10579.jpg  cat.1594.jpg   cat.3847.jpg  cat.6099.jpg  cat.8339.jpg
# cat.10581.jpg  cat.1596.jpg   cat.3848.jpg  cat.609.jpg   cat.833.jpg
# cat.10582.jpg  cat.1597.jpg   cat.3849.jpg  cat.6100.jpg  cat.8341.jpg
# cat.10583.jpg  cat.1599.jpg   cat.384.jpg   cat.6101.jpg  cat.8342.jpg
# cat.10584.jpg  cat.159.jpg    cat.3850.jpg  cat.6102.jpg  cat.8343.jpg
# cat.10585.jpg  cat.15.jpg     cat.3851.jpg  cat.6103.jpg  cat.8345.jpg
# cat.10586.jpg  cat.1600.jpg   cat.3852.jpg  cat.6104.jpg  cat.8347.jpg
# cat.10587.jpg  cat.1601.jpg   cat.3853.jpg  cat.6105.jpg  cat.8348.jpg
# cat.10588.jpg  cat.1602.jpg   cat.3854.jpg  cat.6106.jpg  cat.8349.jpg
# cat.10589.jpg  cat.1603.jpg   cat.3855.jpg  cat.6107.jpg  cat.834.jpg
# cat.1058.jpg   cat.1604.jpg   cat.3856.jpg  cat.6108.jpg  cat.8350.jpg
# cat.10590.jpg  cat.1605.jpg   cat.3857.jpg  cat.6109.jpg  cat.8351.jpg
# cat.10591.jpg  cat.1606.jpg   cat.3858.jpg  cat.610.jpg   cat.8352.jpg
# cat.10593.jpg  cat.1608.jpg   cat.3859.jpg  cat.6110.jpg  cat.8353.jpg
# cat.10594.jpg  cat.1609.jpg   cat.385.jpg   cat.6111.jpg  cat.8354.jpg
# cat.10595.jpg  cat.160.jpg    cat.3860.jpg  cat.6112.jpg  cat.8358.jpg
# cat.10596.jpg  cat.1610.jpg   cat.3862.jpg  cat.6113.jpg  cat.8359.jpg
# cat.10597.jpg  cat.1611.jpg   cat.3863.jpg  cat.6114.jpg  cat.835.jpg
# cat.10598.jpg  cat.1613.jpg   cat.3864.jpg  cat.6115.jpg  cat.8360.jpg
# cat.1059.jpg   cat.1614.jpg   cat.3865.jpg  cat.6116.jpg  cat.8361.jpg
# cat.105.jpg    cat.1615.jpg   cat.3866.jpg  cat.6117.jpg  cat.8362.jpg
# cat.10600.jpg  cat.1616.jpg   cat.3867.jpg  cat.6119.jpg  cat.8363.jpg
# cat.10601.jpg  cat.1617.jpg   cat.3869.jpg  cat.6120.jpg  cat.8364.jpg
# cat.10602.jpg  cat.1619.jpg   cat.386.jpg   cat.6121.jpg  cat.8365.jpg
# cat.10603.jpg  cat.161.jpg    cat.3870.jpg  cat.6122.jpg  cat.8366.jpg
# cat.10604.jpg  cat.1620.jpg   cat.3872.jpg  cat.6123.jpg  cat.8367.jpg
# cat.10606.jpg  cat.1621.jpg   cat.3873.jpg  cat.6124.jpg  cat.8368.jpg
# cat.10607.jpg  cat.1622.jpg   cat.3875.jpg  cat.6125.jpg  cat.8369.jpg
# cat.10608.jpg  cat.1623.jpg   cat.3876.jpg  cat.6126.jpg  cat.836.jpg
# cat.10609.jpg  cat.1624.jpg   cat.3877.jpg  cat.6127.jpg  cat.8370.jpg
# cat.1060.jpg   cat.1625.jpg   cat.3878.jpg  cat.6128.jpg  cat.8372.jpg
# cat.10610.jpg  cat.1626.jpg   cat.3879.jpg  cat.6129.jpg  cat.8373.jpg
# cat.10611.jpg  cat.1627.jpg   cat.387.jpg   cat.612.jpg   cat.8375.jpg
# cat.10612.jpg  cat.1628.jpg   cat.3880.jpg  cat.6130.jpg  cat.8376.jpg
# cat.10613.jpg  cat.1629.jpg   cat.3882.jpg  cat.6131.jpg  cat.8377.jpg
# cat.10614.jpg  cat.162.jpg    cat.3883.jpg  cat.6132.jpg  cat.8378.jpg
# cat.10615.jpg  cat.1630.jpg   cat.3884.jpg  cat.6133.jpg  cat.8379.jpg
# cat.10616.jpg  cat.1631.jpg   cat.3885.jpg  cat.6134.jpg  cat.8380.jpg
# cat.10617.jpg  cat.1632.jpg   cat.3886.jpg  cat.6135.jpg  cat.8381.jpg
# cat.10618.jpg  cat.1633.jpg   cat.3887.jpg  cat.6136.jpg  cat.8382.jpg
# cat.10619.jpg  cat.1634.jpg   cat.3888.jpg  cat.6138.jpg  cat.8383.jpg
# cat.1061.jpg   cat.1635.jpg   cat.3889.jpg  cat.6139.jpg  cat.8384.jpg
# cat.10620.jpg  cat.1636.jpg   cat.388.jpg   cat.613.jpg   cat.8385.jpg
# cat.10621.jpg  cat.1637.jpg   cat.3890.jpg  cat.6140.jpg  cat.8387.jpg
# cat.10622.jpg  cat.1638.jpg   cat.3891.jpg  cat.6141.jpg  cat.8388.jpg
# cat.10623.jpg  cat.1639.jpg   cat.3892.jpg  cat.6142.jpg  cat.8389.jpg
# cat.10624.jpg  cat.163.jpg    cat.3893.jpg  cat.6143.jpg  cat.838.jpg
# cat.10625.jpg  cat.1640.jpg   cat.3894.jpg  cat.6144.jpg  cat.8390.jpg
# cat.10626.jpg  cat.1641.jpg   cat.3895.jpg  cat.6145.jpg  cat.8391.jpg
# cat.10627.jpg  cat.1642.jpg   cat.3896.jpg  cat.6146.jpg  cat.8392.jpg
# cat.10629.jpg  cat.1643.jpg   cat.3898.jpg  cat.6147.jpg  cat.8394.jpg
# cat.1062.jpg   cat.1644.jpg   cat.3899.jpg  cat.6148.jpg  cat.8395.jpg
# cat.10630.jpg  cat.1645.jpg   cat.389.jpg   cat.6149.jpg  cat.8396.jpg
# cat.10631.jpg  cat.1646.jpg   cat.38.jpg    cat.614.jpg   cat.8397.jpg
# cat.10633.jpg  cat.1647.jpg   cat.3900.jpg  cat.6150.jpg  cat.8398.jpg
# cat.10634.jpg  cat.1648.jpg   cat.3901.jpg  cat.6152.jpg  cat.8399.jpg
# cat.10635.jpg  cat.1649.jpg   cat.3902.jpg  cat.6153.jpg  cat.839.jpg
# cat.10636.jpg  cat.1650.jpg   cat.3904.jpg  cat.6154.jpg  cat.83.jpg
# cat.10637.jpg  cat.1652.jpg   cat.3905.jpg  cat.6155.jpg  cat.8400.jpg
# cat.10638.jpg  cat.1654.jpg   cat.3906.jpg  cat.6156.jpg  cat.8401.jpg
# cat.10639.jpg  cat.1655.jpg   cat.3907.jpg  cat.6157.jpg  cat.8402.jpg
# cat.1063.jpg   cat.1656.jpg   cat.3908.jpg  cat.6158.jpg  cat.8403.jpg
# cat.10640.jpg  cat.1657.jpg   cat.3909.jpg  cat.6159.jpg  cat.8404.jpg
# cat.10641.jpg  cat.1658.jpg   cat.390.jpg   cat.615.jpg   cat.8405.jpg
# cat.10642.jpg  cat.1660.jpg   cat.3911.jpg  cat.6160.jpg  cat.8406.jpg
# cat.10643.jpg  cat.1661.jpg   cat.3912.jpg  cat.6161.jpg  cat.8407.jpg
# cat.10644.jpg  cat.1662.jpg   cat.3913.jpg  cat.6162.jpg  cat.8408.jpg
# cat.10645.jpg  cat.1663.jpg   cat.3914.jpg  cat.6163.jpg  cat.8409.jpg
# cat.10646.jpg  cat.1664.jpg   cat.3915.jpg  cat.6164.jpg  cat.840.jpg
# cat.10647.jpg  cat.1665.jpg   cat.3916.jpg  cat.6165.jpg  cat.8410.jpg
# ...
# cat.12028.jpg  cat.3034.jpg   cat.5285.jpg  cat.7536.jpg  cat.9774.jpg
# cat.12029.jpg  cat.3036.jpg   cat.5286.jpg  cat.7537.jpg  cat.9777.jpg
# cat.1202.jpg   cat.3037.jpg   cat.5287.jpg  cat.7538.jpg  cat.9779.jpg
# cat.12030.jpg  cat.3038.jpg   cat.5288.jpg  cat.7539.jpg  cat.977.jpg
# cat.12031.jpg  cat.3039.jpg   cat.5289.jpg  cat.753.jpg   cat.9780.jpg
# cat.12032.jpg  cat.303.jpg    cat.528.jpg   cat.7540.jpg  cat.9781.jpg
# cat.12033.jpg  cat.3040.jpg   cat.5290.jpg  cat.7541.jpg  cat.9782.jpg
# cat.12035.jpg  cat.3041.jpg   cat.5292.jpg  cat.7542.jpg  cat.9783.jpg
# cat.12036.jpg  cat.3042.jpg   cat.5293.jpg  cat.7544.jpg  cat.9784.jpg
# cat.12037.jpg  cat.3043.jpg   cat.5294.jpg  cat.7545.jpg  cat.9786.jpg
# cat.12038.jpg  cat.3044.jpg   cat.5295.jpg  cat.7546.jpg  cat.9788.jpg
# cat.12039.jpg  cat.3045.jpg   cat.5296.jpg  cat.7547.jpg  cat.9789.jpg
# cat.1203.jpg   cat.3046.jpg   cat.5297.jpg  cat.7548.jpg  cat.978.jpg
# cat.12040.jpg  cat.3047.jpg   cat.5298.jpg  cat.7549.jpg  cat.9790.jpg
# cat.12041.jpg  cat.3048.jpg   cat.5299.jpg  cat.754.jpg   cat.9791.jpg
# cat.12042.jpg  cat.3049.jpg   cat.529.jpg   cat.7550.jpg  cat.9792.jpg
# cat.12043.jpg  cat.304.jpg    cat.52.jpg    cat.7551.jpg  cat.9793.jpg
# cat.12044.jpg  cat.3050.jpg   cat.5300.jpg  cat.7552.jpg  cat.9794.jpg
# cat.12046.jpg  cat.3051.jpg   cat.5301.jpg  cat.7553.jpg  cat.9795.jpg
# cat.12047.jpg  cat.3052.jpg   cat.5302.jpg  cat.7554.jpg  cat.9796.jpg
# cat.12048.jpg  cat.3053.jpg   cat.5303.jpg  cat.7555.jpg  cat.9797.jpg
# cat.12049.jpg  cat.3054.jpg   cat.5305.jpg  cat.7556.jpg  cat.9798.jpg
# cat.1204.jpg   cat.3055.jpg   cat.5306.jpg  cat.7558.jpg  cat.9799.jpg
# cat.12050.jpg  cat.3056.jpg   cat.5307.jpg  cat.7559.jpg  cat.979.jpg
# cat.12051.jpg  cat.3057.jpg   cat.5308.jpg  cat.7560.jpg  cat.97.jpg
# cat.12052.jpg  cat.3058.jpg   cat.5309.jpg  cat.7561.jpg  cat.9800.jpg
# cat.12053.jpg  cat.3059.jpg   cat.530.jpg   cat.7563.jpg  cat.9801.jpg
# cat.12054.jpg  cat.305.jpg    cat.5310.jpg  cat.7564.jpg  cat.9802.jpg
# cat.12055.jpg  cat.3060.jpg   cat.5311.jpg  cat.7565.jpg  cat.9803.jpg
# cat.12056.jpg  cat.3061.jpg   cat.5312.jpg  cat.7566.jpg  cat.9804.jpg
# cat.12057.jpg  cat.3062.jpg   cat.5313.jpg  cat.7567.jpg  cat.9805.jpg
# cat.12059.jpg  cat.3063.jpg   cat.5314.jpg  cat.7568.jpg  cat.9806.jpg
# cat.1205.jpg   cat.3065.jpg   cat.5316.jpg  cat.7569.jpg  cat.9807.jpg
# cat.12060.jpg  cat.3066.jpg   cat.5317.jpg  cat.756.jpg   cat.9808.jpg
# cat.12061.jpg  cat.3067.jpg   cat.5318.jpg  cat.7570.jpg  cat.9809.jpg
# cat.12062.jpg  cat.3068.jpg   cat.5319.jpg  cat.7571.jpg  cat.9810.jpg
# cat.12063.jpg  cat.3069.jpg   cat.531.jpg   cat.7572.jpg  cat.9811.jpg
# cat.12064.jpg  cat.306.jpg    cat.5320.jpg  cat.7573.jpg  cat.9812.jpg
# cat.12065.jpg  cat.3070.jpg   cat.5321.jpg  cat.7574.jpg  cat.9813.jpg
# cat.12066.jpg  cat.3071.jpg   cat.5322.jpg  cat.7576.jpg  cat.9814.jpg
# cat.12067.jpg  cat.3072.jpg   cat.5323.jpg  cat.7577.jpg  cat.9815.jpg
# cat.12068.jpg  cat.3073.jpg   cat.5324.jpg  cat.7578.jpg  cat.9816.jpg
# cat.12069.jpg  cat.3074.jpg   cat.5325.jpg  cat.7579.jpg  cat.9817.jpg
# cat.1206.jpg   cat.3075.jpg   cat.5326.jpg  cat.757.jpg   cat.9818.jpg
# cat.12070.jpg  cat.3076.jpg   cat.5327.jpg  cat.7580.jpg  cat.9819.jpg
# cat.12071.jpg  cat.3077.jpg   cat.5328.jpg  cat.7581.jpg  cat.981.jpg
# cat.12072.jpg  cat.3078.jpg   cat.5329.jpg  cat.7583.jpg  cat.9820.jpg
# cat.12073.jpg  cat.3079.jpg   cat.532.jpg   cat.7584.jpg  cat.9822.jpg
# cat.12074.jpg  cat.307.jpg    cat.5330.jpg  cat.7585.jpg  cat.9824.jpg
# cat.12078.jpg  cat.3080.jpg   cat.5331.jpg  cat.7586.jpg  cat.9825.jpg
# cat.1207.jpg   cat.3081.jpg   cat.5332.jpg  cat.7587.jpg  cat.9826.jpg
# cat.12080.jpg  cat.3082.jpg   cat.5333.jpg  cat.7588.jpg  cat.9827.jpg
# cat.12081.jpg  cat.3083.jpg   cat.5334.jpg  cat.7589.jpg  cat.9828.jpg
# cat.12082.jpg  cat.3084.jpg   cat.5336.jpg  cat.758.jpg   cat.9829.jpg
# cat.12083.jpg  cat.3085.jpg   cat.5337.jpg  cat.7590.jpg  cat.982.jpg
# cat.12085.jpg  cat.3086.jpg   cat.5339.jpg  cat.7591.jpg  cat.9830.jpg
# cat.12086.jpg  cat.3087.jpg   cat.533.jpg   cat.7592.jpg  cat.9831.jpg
# cat.12087.jpg  cat.3088.jpg   cat.5340.jpg  cat.7593.jpg  cat.9833.jpg
# cat.12088.jpg  cat.3089.jpg   cat.5341.jpg  cat.7594.jpg  cat.9834.jpg
# cat.12089.jpg  cat.308.jpg    cat.5342.jpg  cat.7595.jpg  cat.9835.jpg
# cat.1208.jpg   cat.3090.jpg   cat.5343.jpg  cat.7596.jpg  cat.9836.jpg
# cat.12090.jpg  cat.3091.jpg   cat.5344.jpg  cat.7597.jpg  cat.9838.jpg
# cat.12091.jpg  cat.3092.jpg   cat.5345.jpg  cat.7598.jpg  cat.983.jpg
# cat.12092.jpg  cat.3093.jpg   cat.5346.jpg  cat.7599.jpg  cat.9840.jpg
# cat.12093.jpg  cat.3094.jpg   cat.5347.jpg  cat.759.jpg   cat.9841.jpg
# cat.12094.jpg  cat.3095.jpg   cat.5348.jpg  cat.75.jpg	  cat.9843.jpg
# cat.12095.jpg  cat.3096.jpg   cat.5349.jpg  cat.7600.jpg  cat.9844.jpg
# cat.12096.jpg  cat.3097.jpg   cat.534.jpg   cat.7601.jpg  cat.9845.jpg
# cat.12097.jpg  cat.3098.jpg   cat.5350.jpg  cat.7602.jpg  cat.9846.jpg
# cat.12098.jpg  cat.3099.jpg   cat.5351.jpg  cat.7604.jpg  cat.9848.jpg
# cat.12099.jpg  cat.309.jpg    cat.5352.jpg  cat.7605.jpg  cat.9849.jpg
# cat.1209.jpg   cat.30.jpg     cat.5353.jpg  cat.7606.jpg  cat.984.jpg
# cat.120.jpg    cat.3100.jpg   cat.5354.jpg  cat.7607.jpg  cat.9850.jpg
# cat.12100.jpg  cat.3101.jpg   cat.5355.jpg  cat.7608.jpg  cat.9851.jpg
# cat.12101.jpg  cat.3102.jpg   cat.5356.jpg  cat.7609.jpg  cat.9852.jpg
# cat.12102.jpg  cat.3103.jpg   cat.5357.jpg  cat.760.jpg   cat.9853.jpg
# cat.12103.jpg  cat.3104.jpg   cat.5358.jpg  cat.7610.jpg  cat.9854.jpg
# cat.12104.jpg  cat.3105.jpg   cat.5359.jpg  cat.7611.jpg  cat.9855.jpg
# cat.12105.jpg  cat.3106.jpg   cat.535.jpg   cat.7612.jpg  cat.9856.jpg
# cat.12106.jpg  cat.3107.jpg   cat.5360.jpg  cat.7613.jpg  cat.9857.jpg
# cat.12107.jpg  cat.3108.jpg   cat.5361.jpg  cat.7614.jpg  cat.9858.jpg
# cat.12108.jpg  cat.3109.jpg   cat.5362.jpg  cat.7615.jpg  cat.9859.jpg
# cat.12109.jpg  cat.310.jpg    cat.5363.jpg  cat.7616.jpg  cat.985.jpg
# cat.1210.jpg   cat.3110.jpg   cat.5364.jpg  cat.7617.jpg  cat.9860.jpg
# cat.12110.jpg  cat.3112.jpg   cat.5365.jpg  cat.7618.jpg  cat.9861.jpg
# cat.12111.jpg  cat.3113.jpg   cat.5366.jpg  cat.7619.jpg  cat.9862.jpg
# cat.12113.jpg  cat.3114.jpg   cat.5367.jpg  cat.761.jpg   cat.9863.jpg
# cat.12114.jpg  cat.3115.jpg   cat.5369.jpg  cat.7620.jpg  cat.9864.jpg
# cat.12115.jpg  cat.3116.jpg   cat.536.jpg   cat.7621.jpg  cat.9866.jpg
# cat.12116.jpg  cat.3117.jpg   cat.5370.jpg  cat.7622.jpg  cat.9867.jpg
# cat.1211.jpg   cat.3118.jpg   cat.5371.jpg  cat.7623.jpg  cat.9869.jpg
# cat.12120.jpg  cat.3119.jpg   cat.5372.jpg  cat.7624.jpg  cat.986.jpg
# cat.12121.jpg  cat.311.jpg    cat.5373.jpg  cat.7625.jpg  cat.9870.jpg
# cat.12122.jpg  cat.3120.jpg   cat.5374.jpg  cat.7626.jpg  cat.9871.jpg
# cat.12123.jpg  cat.3121.jpg   cat.5375.jpg  cat.7627.jpg  cat.9872.jpg
# cat.12124.jpg  cat.3122.jpg   cat.5376.jpg  cat.7628.jpg  cat.9873.jpg
# cat.12125.jpg  cat.3123.jpg   cat.5378.jpg  cat.7629.jpg  cat.9874.jpg
# cat.12126.jpg  cat.3124.jpg   cat.5379.jpg  cat.762.jpg   cat.9875.jpg
# cat.12127.jpg  cat.3125.jpg   cat.537.jpg   cat.7630.jpg  cat.9876.jpg
# cat.12128.jpg  cat.3126.jpg   cat.5380.jpg  cat.7631.jpg  cat.9877.jpg
# cat.12129.jpg  cat.3127.jpg   cat.5381.jpg  cat.7632.jpg  cat.9878.jpg
# cat.1212.jpg   cat.3129.jpg   cat.5382.jpg  cat.7633.jpg  cat.9879.jpg
# cat.12130.jpg  cat.3130.jpg   cat.5383.jpg  cat.7634.jpg  cat.987.jpg
# cat.12131.jpg  cat.3131.jpg   cat.5384.jpg  cat.7635.jpg  cat.9881.jpg
# cat.12132.jpg  cat.3132.jpg   cat.5385.jpg  cat.7636.jpg  cat.9882.jpg
# cat.12133.jpg  cat.3133.jpg   cat.5386.jpg  cat.7637.jpg  cat.9884.jpg
# cat.12134.jpg  cat.3134.jpg   cat.5387.jpg  cat.7638.jpg  cat.9885.jpg
# cat.12135.jpg  cat.3136.jpg   cat.5388.jpg  cat.7639.jpg  cat.9886.jpg
# cat.12136.jpg  cat.3137.jpg   cat.5389.jpg  cat.763.jpg   cat.9887.jpg
# cat.12137.jpg  cat.3139.jpg   cat.538.jpg   cat.7640.jpg  cat.9888.jpg
# cat.12138.jpg  cat.313.jpg    cat.5390.jpg  cat.7641.jpg  cat.988.jpg
# cat.12139.jpg  cat.3140.jpg   cat.5391.jpg  cat.7642.jpg  cat.9890.jpg
# cat.1213.jpg   cat.3141.jpg   cat.5392.jpg  cat.7643.jpg  cat.9891.jpg
# cat.12140.jpg  cat.3142.jpg   cat.5393.jpg  cat.7644.jpg  cat.9892.jpg
# cat.12141.jpg  cat.3143.jpg   cat.5394.jpg  cat.7645.jpg  cat.9893.jpg
# cat.12142.jpg  cat.3144.jpg   cat.5395.jpg  cat.7646.jpg  cat.9894.jpg
# cat.12143.jpg  cat.3145.jpg   cat.5396.jpg  cat.7647.jpg  cat.9895.jpg
# cat.12144.jpg  cat.3146.jpg   cat.5397.jpg  cat.7648.jpg  cat.9896.jpg
# cat.12145.jpg  cat.3147.jpg   cat.5398.jpg  cat.7649.jpg  cat.9897.jpg
# cat.12146.jpg  cat.3148.jpg   cat.53.jpg    cat.764.jpg   cat.9898.jpg
# cat.12147.jpg  cat.3149.jpg   cat.5400.jpg  cat.7650.jpg  cat.9899.jpg
# cat.12148.jpg  cat.314.jpg    cat.5401.jpg  cat.7651.jpg  cat.98.jpg
# cat.12149.jpg  cat.3150.jpg   cat.5402.jpg  cat.7652.jpg  cat.9900.jpg
# cat.1214.jpg   cat.3151.jpg   cat.5403.jpg  cat.7653.jpg  cat.9901.jpg
# cat.12150.jpg  cat.3152.jpg   cat.5404.jpg  cat.7654.jpg  cat.9903.jpg
# cat.12151.jpg  cat.3153.jpg   cat.5405.jpg  cat.7655.jpg  cat.9904.jpg
# cat.12152.jpg  cat.3154.jpg   cat.5406.jpg  cat.7656.jpg  cat.9905.jpg
# cat.12153.jpg  cat.3155.jpg   cat.5407.jpg  cat.7657.jpg  cat.9906.jpg
# cat.12155.jpg  cat.3156.jpg   cat.5408.jpg  cat.7658.jpg  cat.9907.jpg
# cat.12156.jpg  cat.3157.jpg   cat.5409.jpg  cat.7659.jpg  cat.9908.jpg
# cat.12157.jpg  cat.3158.jpg   cat.540.jpg   cat.765.jpg   cat.9909.jpg
# cat.12158.jpg  cat.3159.jpg   cat.5410.jpg  cat.7660.jpg  cat.990.jpg
# cat.12159.jpg  cat.315.jpg    cat.5411.jpg  cat.7661.jpg  cat.9910.jpg
# cat.1215.jpg   cat.3160.jpg   cat.5412.jpg  cat.7662.jpg  cat.9911.jpg
# cat.12160.jpg  cat.3161.jpg   cat.5413.jpg  cat.7663.jpg  cat.9912.jpg
# cat.12161.jpg  cat.3162.jpg   cat.5414.jpg  cat.7664.jpg  cat.9913.jpg
# cat.12162.jpg  cat.3163.jpg   cat.5415.jpg  cat.7666.jpg  cat.9914.jpg
# cat.12163.jpg  cat.3164.jpg   cat.5416.jpg  cat.7667.jpg  cat.9915.jpg
# cat.12164.jpg  cat.3166.jpg   cat.5417.jpg  cat.7668.jpg  cat.9916.jpg
# cat.12165.jpg  cat.3167.jpg   cat.5418.jpg  cat.7669.jpg  cat.9917.jpg
# cat.12166.jpg  cat.3168.jpg   cat.5419.jpg  cat.766.jpg   cat.9918.jpg
# cat.12168.jpg  cat.3169.jpg   cat.541.jpg   cat.7671.jpg  cat.991.jpg
# cat.12169.jpg  cat.316.jpg    cat.5420.jpg  cat.7673.jpg  cat.9920.jpg
# cat.1216.jpg   cat.3171.jpg   cat.5421.jpg  cat.7674.jpg  cat.9921.jpg
# cat.12171.jpg  cat.3174.jpg   cat.5422.jpg  cat.7675.jpg  cat.9922.jpg
# cat.12172.jpg  cat.3175.jpg   cat.5423.jpg  cat.7676.jpg  cat.9924.jpg
# cat.12173.jpg  cat.3176.jpg   cat.5425.jpg  cat.7677.jpg  cat.9926.jpg
# cat.12174.jpg  cat.3177.jpg   cat.5426.jpg  cat.7678.jpg  cat.9927.jpg
# cat.12175.jpg  cat.3178.jpg   cat.5427.jpg  cat.7679.jpg  cat.9928.jpg
# cat.12176.jpg  cat.3179.jpg   cat.5428.jpg  cat.767.jpg   cat.9929.jpg
# cat.12177.jpg  cat.317.jpg    cat.542.jpg   cat.7680.jpg  cat.992.jpg
# cat.12178.jpg  cat.3180.jpg   cat.5430.jpg  cat.7681.jpg  cat.9930.jpg
# cat.12179.jpg  cat.3181.jpg   cat.5431.jpg  cat.7682.jpg  cat.9931.jpg
# cat.1217.jpg   cat.3182.jpg   cat.5433.jpg  cat.7683.jpg  cat.9932.jpg
# cat.12180.jpg  cat.3183.jpg   cat.5434.jpg  cat.7684.jpg  cat.9933.jpg
# cat.12181.jpg  cat.3185.jpg   cat.5435.jpg  cat.7685.jpg  cat.9934.jpg
# cat.12182.jpg  cat.3186.jpg   cat.5436.jpg  cat.7686.jpg  cat.9935.jpg
# cat.12183.jpg  cat.3187.jpg   cat.5437.jpg  cat.7687.jpg  cat.9936.jpg
# cat.12185.jpg  cat.3188.jpg   cat.5439.jpg  cat.7688.jpg  cat.9937.jpg
# cat.12186.jpg  cat.3189.jpg   cat.543.jpg   cat.7689.jpg  cat.9938.jpg
# cat.12187.jpg  cat.318.jpg    cat.5440.jpg  cat.768.jpg   cat.9939.jpg
# cat.12188.jpg  cat.3190.jpg   cat.5441.jpg  cat.7690.jpg  cat.993.jpg
# cat.12189.jpg  cat.3191.jpg   cat.5442.jpg  cat.7691.jpg  cat.9940.jpg
# cat.1218.jpg   cat.3192.jpg   cat.5443.jpg  cat.7692.jpg  cat.9941.jpg
# cat.12190.jpg  cat.3193.jpg   cat.5444.jpg  cat.7693.jpg  cat.9942.jpg
# cat.12191.jpg  cat.3195.jpg   cat.5445.jpg  cat.7694.jpg  cat.9943.jpg
# cat.12192.jpg  cat.3196.jpg   cat.5446.jpg  cat.7695.jpg  cat.9944.jpg
# cat.12193.jpg  cat.3197.jpg   cat.5447.jpg  cat.7696.jpg  cat.9945.jpg
# cat.12194.jpg  cat.3198.jpg   cat.5448.jpg  cat.7697.jpg  cat.9946.jpg
# cat.12196.jpg  cat.3199.jpg   cat.544.jpg   cat.7698.jpg  cat.9947.jpg
# cat.12197.jpg  cat.319.jpg    cat.5450.jpg  cat.7699.jpg  cat.9948.jpg
# cat.12198.jpg  cat.31.jpg     cat.5451.jpg  cat.769.jpg   cat.9949.jpg
# cat.12199.jpg  cat.3200.jpg   cat.5453.jpg  cat.76.jpg	  cat.994.jpg
# cat.1219.jpg   cat.3201.jpg   cat.5454.jpg  cat.7700.jpg  cat.9950.jpg
# cat.121.jpg    cat.3202.jpg   cat.5455.jpg  cat.7701.jpg  cat.9951.jpg
# cat.12201.jpg  cat.3203.jpg   cat.5456.jpg  cat.7702.jpg  cat.9952.jpg
# cat.12202.jpg  cat.3204.jpg   cat.5457.jpg  cat.7703.jpg  cat.9953.jpg
# cat.12203.jpg  cat.3205.jpg   cat.5458.jpg  cat.7704.jpg  cat.9954.jpg
# cat.12204.jpg  cat.3206.jpg   cat.5459.jpg  cat.7705.jpg  cat.9955.jpg
# cat.12205.jpg  cat.3207.jpg   cat.5460.jpg  cat.7706.jpg  cat.9956.jpg
# cat.12206.jpg  cat.3208.jpg   cat.5461.jpg  cat.7707.jpg  cat.9957.jpg
# cat.12207.jpg  cat.320.jpg    cat.5462.jpg  cat.7708.jpg  cat.9958.jpg
# cat.12208.jpg  cat.3210.jpg   cat.5464.jpg  cat.7709.jpg  cat.995.jpg
# cat.12209.jpg  cat.3211.jpg   cat.5465.jpg  cat.770.jpg   cat.9960.jpg
# cat.1220.jpg   cat.3212.jpg   cat.5466.jpg  cat.7710.jpg  cat.9961.jpg
# cat.12210.jpg  cat.3213.jpg   cat.5467.jpg  cat.7711.jpg  cat.9962.jpg
# cat.12211.jpg  cat.3214.jpg   cat.5468.jpg  cat.7712.jpg  cat.9963.jpg
# cat.12212.jpg  cat.3215.jpg   cat.5469.jpg  cat.7713.jpg  cat.9964.jpg
# cat.12213.jpg  cat.3216.jpg   cat.546.jpg   cat.7715.jpg  cat.9965.jpg
# cat.12214.jpg  cat.3217.jpg   cat.5470.jpg  cat.7716.jpg  cat.9966.jpg
# cat.12215.jpg  cat.3218.jpg   cat.5471.jpg  cat.7717.jpg  cat.9967.jpg
# cat.12216.jpg  cat.3219.jpg   cat.5472.jpg  cat.7718.jpg  cat.9968.jpg
# cat.12217.jpg  cat.321.jpg    cat.5473.jpg  cat.7719.jpg  cat.9969.jpg
# cat.12218.jpg  cat.3220.jpg   cat.5474.jpg  cat.771.jpg   cat.996.jpg
# cat.12219.jpg  cat.3221.jpg   cat.5475.jpg  cat.7720.jpg  cat.9971.jpg
# cat.1221.jpg   cat.3222.jpg   cat.5476.jpg  cat.7721.jpg  cat.9972.jpg
# cat.12220.jpg  cat.3223.jpg   cat.5477.jpg  cat.7722.jpg  cat.9973.jpg
# cat.12221.jpg  cat.3224.jpg   cat.5478.jpg  cat.7724.jpg  cat.9974.jpg
# cat.12222.jpg  cat.3226.jpg   cat.5479.jpg  cat.7725.jpg  cat.9975.jpg
# cat.12223.jpg  cat.3227.jpg   cat.547.jpg   cat.7726.jpg  cat.9976.jpg
# cat.12224.jpg  cat.3228.jpg   cat.5480.jpg  cat.7727.jpg  cat.9977.jpg
# cat.12225.jpg  cat.3229.jpg   cat.5481.jpg  cat.7729.jpg  cat.9978.jpg
# cat.12227.jpg  cat.322.jpg    cat.5483.jpg  cat.772.jpg   cat.997.jpg
# cat.12228.jpg  cat.3231.jpg   cat.5484.jpg  cat.7730.jpg  cat.9980.jpg
# cat.12229.jpg  cat.3232.jpg   cat.5485.jpg  cat.7731.jpg  cat.9981.jpg
# cat.1222.jpg   cat.3233.jpg   cat.5486.jpg  cat.7732.jpg  cat.9982.jpg
# cat.12230.jpg  cat.3234.jpg   cat.5487.jpg  cat.7733.jpg  cat.9983.jpg
# cat.12231.jpg  cat.3235.jpg   cat.5488.jpg  cat.7734.jpg  cat.9984.jpg
# cat.12232.jpg  cat.3236.jpg   cat.5489.jpg  cat.7735.jpg  cat.9985.jpg
# cat.12233.jpg  cat.3237.jpg   cat.548.jpg   cat.7736.jpg  cat.9987.jpg
# cat.12234.jpg  cat.3238.jpg   cat.5490.jpg  cat.7737.jpg  cat.9988.jpg
# cat.12235.jpg  cat.323.jpg    cat.5491.jpg  cat.7738.jpg  cat.9989.jpg
# cat.12236.jpg  cat.3240.jpg   cat.5492.jpg  cat.7739.jpg  cat.998.jpg
# cat.12237.jpg  cat.3241.jpg   cat.5494.jpg  cat.773.jpg   cat.9990.jpg
# cat.12238.jpg  cat.3242.jpg   cat.5495.jpg  cat.7740.jpg  cat.9991.jpg
# cat.1223.jpg   cat.3243.jpg   cat.5496.jpg  cat.7742.jpg  cat.9992.jpg
# cat.12240.jpg  cat.3244.jpg   cat.5497.jpg  cat.7743.jpg  cat.9993.jpg
# cat.12241.jpg  cat.3245.jpg   cat.5498.jpg  cat.7744.jpg  cat.9994.jpg
# cat.12242.jpg  cat.3246.jpg   cat.5499.jpg  cat.7745.jpg  cat.9995.jpg
# cat.12243.jpg  cat.3247.jpg   cat.549.jpg   cat.7747.jpg  cat.9996.jpg
# cat.12244.jpg  cat.3248.jpg   cat.54.jpg    cat.7748.jpg  cat.9997.jpg
# cat.12245.jpg  cat.3249.jpg   cat.5500.jpg  cat.7749.jpg  cat.9999.jpg
# cat.12246.jpg  cat.324.jpg    cat.5501.jpg  cat.774.jpg   cat.999.jpg
# cat.12247.jpg  cat.3250.jpg   cat.5502.jpg  cat.7750.jpg  cat.99.jpg
# cat.12248.jpg  cat.3251.jpg   cat.5503.jpg  cat.7751.jpg  cat.9.jpg

# %% [markdown]
# Let's take a look at how this generator changes a single image (the details of this code don't matter much, but feel free to read the comments and keras docs to understand the details if you're interested).

# %%
# Create a 'batch' of a single image
img = np.expand_dims(ndimage.imread('data/dogscats/train/cats/cat.1000.jpg'),0)
# Request the generator to create batches from this image
aug_iter = gen.flow(img)

# %%
# Get eight examples of these augmented images
aug_imgs = [next(aug_iter)[0].astype(np.uint8) for i in range(8)]

# %%
# The original
plt.imshow(img[0])

# %% [markdown]
# As you can see below, there's no magic to data augmentation - it's a very intuitive approach to generating richer input data. Generally speaking, your intuition should be a good guide to appropriate data augmentation, although it's a good idea to test your intuition by checking the results of different augmentation approaches.

# %%
# Augmented data
plots(aug_imgs, (20,7), 2)

# %%
# Ensure that we return to theano dimension ordering
K.set_image_dim_ordering('th')

# %% [markdown]
# ## Adding data augmentation

# %% [markdown]
# Let's try adding a small amount of data augmentation, and see if we reduce overfitting as a result. The approach will be identical to the method we used to finetune the dense layers in lesson 2, except that we will use a generator with augmentation configured. Here's how we set up the generator, and create batches from it:

# %%
gen = image.ImageDataGenerator(rotation_range=15, width_shift_range=0.1, 
                               height_shift_range=0.1, zoom_range=0.1, horizontal_flip=True)

# %%
batches = get_batches(path+'train', gen, batch_size=batch_size)
# NB: We don't want to augment or shuffle the validation set
val_batches = get_batches(path+'valid', shuffle=False, batch_size=batch_size)
# Out:
# Found 23000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# When using data augmentation, we can't pre-compute our convolutional layer features, since randomized changes are being made to every input image. That is, even if the training process sees the same image multiple times, each time it will have undergone different data augmentation, so the results of the convolutional layers will be different.
#
# Therefore, in order to allow data to flow through all the conv layers and our new dense layers, we attach our fully connected model to the convolutional model--after ensuring that the convolutional layers are not trainable:

# %%
fc_model = get_fc_model()

# %%
for layer in conv_model.layers: layer.trainable = False
# Look how easy it is to connect two models together!
conv_model.add(fc_model)

# %% [markdown]
# Now we can compile, train, and save our model as usual - note that we use *fit_generator()* since we want to pull random images from the directories on every batch.

# %%
conv_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# ?conv_model.fit_generator

# %%
epoch_steps = ceil(batches.samples/batches.batch_size)
val_steps = ceil(val_batches.samples/val_batches.batch_size)

conv_model.fit_generator(batches, steps_per_epoch=epoch_steps, epochs=8, 
                        validation_data=val_batches, validation_steps=val_steps)
# Out:
# Epoch 1/8
# 360/360 [==============================] - 189s - loss: 0.3696 - acc: 0.9744 - val_loss: 0.2666 - val_acc: 0.9825
# Epoch 2/8
# 360/360 [==============================] - 179s - loss: 0.3176 - acc: 0.9786 - val_loss: 0.2272 - val_acc: 0.9850
# Epoch 3/8
# 360/360 [==============================] - 180s - loss: 0.3013 - acc: 0.9799 - val_loss: 0.1929 - val_acc: 0.9870
# Epoch 4/8
# 360/360 [==============================] - 186s - loss: 0.2751 - acc: 0.9814 - val_loss: 0.2255 - val_acc: 0.9845
# Epoch 5/8
# 360/360 [==============================] - 182s - loss: 0.2697 - acc: 0.9818 - val_loss: 0.1870 - val_acc: 0.9875
# Epoch 6/8
# 360/360 [==============================] - 185s - loss: 0.2598 - acc: 0.9823 - val_loss: 0.3472 - val_acc: 0.9775
# Epoch 7/8
# 360/360 [==============================] - 181s - loss: 0.2663 - acc: 0.9823 - val_loss: 0.1902 - val_acc: 0.9865
# Epoch 8/8
# 360/360 [==============================] - 180s - loss: 0.2474 - acc: 0.9835 - val_loss: 0.2774 - val_acc: 0.9810

# %%
conv_model.save_weights(model_path + 'aug1.h5')

# %%
conv_model.load_weights(model_path + 'aug1.h5')

# %% [markdown]
# ## Batch normalization

# %% [markdown]
# ### About batch normalization

# %% [markdown]
# Batch normalization (*batchnorm*) is a way to ensure that activations don't become too high or too low at any point in the model. Adjusting activations so they are of similar scales is called *normalization*. Normalization is very helpful for fast training - if some activations are very high, they will saturate the model and create very large gradients, causing training to fail; if very low, they will cause training to proceed very slowly. Furthermore, large or small activations in one layer will tend to result in even larger or smaller activations in later layers, since the activations get multiplied repeatedly across the layers.
#
# Prior to the development of batchnorm in 2015, only the inputs to a model could be effectively normalized - by simply subtracting their mean and dividing by their standard deviation. However, weights in intermediate layers could easily become poorly scaled, due to problems in weight initialization, or a high learning rate combined with random fluctuations in weights.

# %% [markdown]
# Batchnorm resolves this problem by normalizing each intermediate layer as well. The details of how it works are not terribly important (although I will outline them in a moment) - the important takeaway is that **all modern networks should use batchnorm, or something equivalent**. There are two reasons for this:
# 1. Adding batchnorm to a model can result in **10x or more improvements in training speed**
# 2. Because normalization greatly reduces the ability of a small number of outlying inputs to over-influence the training, it also tends to **reduce overfitting**.

# %% [markdown]
# As promised, here's a brief outline of how batchnorm works. As a first step, it normalizes intermediate layers in the same way as input layers can be normalized. But this on its own would not be enough, since the model would then just push the weights up or down indefinitely to try to undo this normalization. Therefore, batchnorm takes two additional steps:
# 1. Add two more trainable parameters to each layer - one to multiply all activations to set an arbitrary standard deviation, and one to add to all activations to set an arbitary mean
# 2. Incorporate both the normalization, and the learnt multiply/add parameters, into the gradient calculations during backprop.
#
# This ensures that the weights don't tend to push very high or very low (since the normalization is included in the gradient calculations, so the updates are aware of the normalization). But it also ensures that if a layer does need to change the overall mean or standard deviation in order to match the output scale, it can do so.

# %% [markdown]
# ### Adding batchnorm to the model

# %% [markdown]
# We can use nearly the same approach as before - but this time we'll add batchnorm layers (and dropout layers):

# %%
conv_layers[-1].output_shape[1:]
# Out:
# (512, 14, 14)

# %%
def get_bn_layers(p):
    return [
        MaxPooling2D(input_shape=conv_layers[-1].output_shape[1:]),
        Flatten(),
        Dense(4096, activation='relu'),
        Dropout(p),
        BatchNormalization(),
        Dense(4096, activation='relu'),
        Dropout(p),
        BatchNormalization(),
        Dense(1000, activation='softmax')
        ]

# %%
p=0.6

# %%
bn_model = Sequential(get_bn_layers(0.6))

# %%
bn_model.load_weights('/data/jhoward/ILSVRC2012_img/bn_do3_1.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-56-eb084393d5fa> in <module>()
# ----> 1 bn_model.load_weights('/data/jhoward/ILSVRC2012_img/bn_do3_1.h5')
#
# /home/karel/anaconda3/lib/python3.6/site-packages/keras/models.py in load_weights(self, filepath, by_name)
#     692         if h5py is None:
#     693             raise ImportError('`load_weights` requires h5py.')
# --> 694         f = h5py.File(filepath, mode='r')
#     695         if 'layer_names' not in f.attrs and 'model_weights' in f:
#     696             f = f['model_weights']
#
# /home/karel/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     269
#     270                 fapl = make_fapl(driver, libver, **kwds)
# --> 271                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     272
#     273                 if swmr_support:
#
# /home/karel/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      99         if swmr and swmr_support:
#     100             flags |= h5f.ACC_SWMR_READ
# --> 101         fid = h5f.open(name, flags, fapl=fapl)
#     102     elif mode == 'r+':
#     103         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1490028290543/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1490028290543/work/h5py/_objects.c:2804)()
#
# h5py/h5f.pyx in h5py.h5f.open (/home/ilan/minonda/conda-bld/h5py_1490028290543/work/h5py/h5f.c:2123)()
#
# OSError: Unable to open file (Unable to open file: name = '/data/jhoward/ilsvrc2012_img/bn_do3_1.h5', errno = 2, error message = 'no such file or directory', flags = 0, o_flags = 0)

# %%
def proc_wgts(layer, prev_p, new_p):
    scal = (1-prev_p)/(1-new_p)
    return [o*scal for o in layer.get_weights()]

# %%
for l in bn_model.layers: 
    if type(l)==Dense: l.set_weights(proc_wgts(l, 0.3, 0.6))

# %%
bn_model.pop()
for layer in bn_model.layers: layer.trainable=False

# %%
bn_model.add(Dense(2,activation='softmax'))

# %%
bn_model.compile(Adam(), 'categorical_crossentropy', metrics=['accuracy'])

# %%
bn_model.fit(trn_features, trn_labels, nb_epoch=8, validation_data=(val_features, val_labels))
# Out:
# Train on 23000 samples, validate on 2000 samples
# Epoch 1/8
# 23000/23000 [==============================] - 6s - loss: 0.1800 - acc: 0.9547 - val_loss: 0.1132 - val_acc: 0.9760
# Epoch 2/8
# 23000/23000 [==============================] - 6s - loss: 0.1001 - acc: 0.9650 - val_loss: 0.1019 - val_acc: 0.9795
# Epoch 3/8
# 23000/23000 [==============================] - 6s - loss: 0.0911 - acc: 0.9664 - val_loss: 0.1171 - val_acc: 0.9780
# Epoch 4/8
# 23000/23000 [==============================] - 6s - loss: 0.0894 - acc: 0.9674 - val_loss: 0.1072 - val_acc: 0.9790
# Epoch 5/8
# 23000/23000 [==============================] - 6s - loss: 0.0904 - acc: 0.9658 - val_loss: 0.0891 - val_acc: 0.9800
# Epoch 6/8
# 23000/23000 [==============================] - 6s - loss: 0.0834 - acc: 0.9680 - val_loss: 0.0990 - val_acc: 0.9805
# Epoch 7/8
# 23000/23000 [==============================] - 6s - loss: 0.0831 - acc: 0.9686 - val_loss: 0.0989 - val_acc: 0.9805
# Epoch 8/8
# 23000/23000 [==============================] - 6s - loss: 0.0825 - acc: 0.9684 - val_loss: 0.0907 - val_acc: 0.9795

# %%
bn_model.save_weights(model_path+'bn.h5')

# %%
bn_model.load_weights(model_path+'bn.h5')

# %%
bn_layers = get_bn_layers(0.6)
bn_layers.pop()
bn_layers.append(Dense(2,activation='softmax'))

# %%
final_model = Sequential(conv_layers)
for layer in final_model.layers: layer.trainable = False
for layer in bn_layers: final_model.add(layer)

# %%
for l1,l2 in zip(bn_model.layers, bn_layers):
    l2.set_weights(l1.get_weights())

# %%
final_model.compile(optimizer=Adam(), 
                    loss='categorical_crossentropy', metrics=['accuracy'])

# %%
final_model.fit_generator(batches, samples_per_epoch=batches.nb_sample, nb_epoch=1, 
                        validation_data=val_batches, nb_val_samples=val_batches.nb_sample)
# Out:
# Epoch 1/1
# 23000/23000 [==============================] - 282s - loss: 0.0855 - acc: 0.9677 - val_loss: 0.0609 - val_acc: 0.9830

# %%
final_model.save_weights(model_path + 'final1.h5')

# %%
final_model.fit_generator(batches, samples_per_epoch=batches.nb_sample, nb_epoch=4, 
                        validation_data=val_batches, nb_val_samples=val_batches.nb_sample)
# Out:
# Epoch 1/4
# 23000/23000 [==============================] - 282s - loss: 0.0734 - acc: 0.9723 - val_loss: 0.0743 - val_acc: 0.9810
# Epoch 2/4
# 23000/23000 [==============================] - 282s - loss: 0.0661 - acc: 0.9760 - val_loss: 0.0490 - val_acc: 0.9840
# Epoch 3/4
# 23000/23000 [==============================] - 282s - loss: 0.0641 - acc: 0.9762 - val_loss: 0.0633 - val_acc: 0.9800
# Epoch 4/4
# 23000/23000 [==============================] - 282s - loss: 0.0579 - acc: 0.9776 - val_loss: 0.0553 - val_acc: 0.9840

# %%
final_model.save_weights(model_path + 'final2.h5')

# %%
final_model.optimizer.lr=0.001

# %%
final_model.fit_generator(batches, samples_per_epoch=batches.nb_sample, nb_epoch=4, 
                        validation_data=val_batches, nb_val_samples=val_batches.nb_sample)
# Out:
# Epoch 1/4
# 23000/23000 [==============================] - 282s - loss: 0.0509 - acc: 0.9810 - val_loss: 0.0748 - val_acc: 0.9835
# Epoch 2/4
# 23000/23000 [==============================] - 282s - loss: 0.0480 - acc: 0.9833 - val_loss: 0.0755 - val_acc: 0.9830
# Epoch 3/4
# 23000/23000 [==============================] - 282s - loss: 0.0538 - acc: 0.9807 - val_loss: 0.0596 - val_acc: 0.9850
# Epoch 4/4
# 23000/23000 [==============================] - 282s - loss: 0.0453 - acc: 0.9834 - val_loss: 0.0616 - val_acc: 0.9860

# %%
bn_model.save_weights(model_path + 'final3.h5')
